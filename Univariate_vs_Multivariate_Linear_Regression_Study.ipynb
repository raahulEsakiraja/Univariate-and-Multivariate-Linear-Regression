# %%
import yfinance as yf
import pandas as pd
import os
from datetime import datetime, timedelta

# List of 20 most instituionally held stocks
tickers = [
    "GOOG", "MSFT", "BRK-B", "AAPL", "AMZN", "JPM", "JNJ",
    "NVDA", "XOM", "V", "PG", "META", "HD", "SPY", "CVX",
    "MRK", "PEP", "ABBV", "UNH", "COST"
]
# Just in case, probably wont work but thats fine
tickers = [ticker.replace('-', '.') for ticker in tickers]

period = "7d"       # The most I can pull given the constraint of 1m
interval = "1m"

# Save Uncleaned Date
output_dir = "yfinance_1m_data"
os.makedirs(output_dir, exist_ok=True)

def download_and_save(ticker, period, interval, output_dir):
    try:
        print(f"Downloading data for {ticker}...")
        data = yf.download(tickers=ticker, period=period, interval=interval, progress=False)

        if data.empty:
            print(f"No data found for {ticker}. It might be due to the period/interval limitations.")
            return

        filename = os.path.join(output_dir, f"{ticker}.csv")

        data.to_csv(filename)
        print(f"Data for {ticker} saved to {filename}")

    except Exception as e:
        print(f"Error downloading data for {ticker}: {e}")

for ticker in tickers:
    download_and_save(ticker, period, interval, output_dir)

print("Data download complete.")
# Out:
# Downloading data for GOOG...
# Data for GOOG saved to yfinance_1m_data/GOOG.csv
# Downloading data for MSFT...
# Data for MSFT saved to yfinance_1m_data/MSFT.csv
# Downloading data for BRK.B...
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK.B']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (period=7d) (Yahoo error = "No data found, symbol may be delisted")')
# No data found for BRK.B. It might be due to the period/interval limitations.
# Downloading data for AAPL...
# Data for AAPL saved to yfinance_1m_data/AAPL.csv
# Downloading data for AMZN...
# Data for AMZN saved to yfinance_1m_data/AMZN.csv
# Downloading data for JPM...
# Data for JPM saved to yfinance_1m_data/JPM.csv
# Downloading data for JNJ...
# Data for JNJ saved to yfinance_1m_data/JNJ.csv
# Downloading data for NVDA...
# Data for NVDA saved to yfinance_1m_data/NVDA.csv
# Downloading data for XOM...
# Data for XOM saved to yfinance_1m_data/XOM.csv
# Downloading data for V...
# Data for V saved to yfinance_1m_data/V.csv
# Downloading data for PG...
# Data for PG saved to yfinance_1m_data/PG.csv
# Downloading data for META...
# Data for META saved to yfinance_1m_data/META.csv
# Downloading data for HD...
# Data for HD saved to yfinance_1m_data/HD.csv
# Downloading data for SPY...
# Data for SPY saved to yfinance_1m_data/SPY.csv
# Downloading data for CVX...
# Data for CVX saved to yfinance_1m_data/CVX.csv
# Downloading data for MRK...
# Data for MRK saved to yfinance_1m_data/MRK.csv
# Downloading data for PEP...
# Data for PEP saved to yfinance_1m_data/PEP.csv
# Downloading data for ABBV...
# Data for ABBV saved to yfinance_1m_data/ABBV.csv
# Downloading data for UNH...
# Data for UNH saved to yfinance_1m_data/UNH.csv
# Downloading data for COST...
# Data for COST saved to yfinance_1m_data/COST.csv
# Data download complete.

# %%
import pandas as pd
import os

input_dir = "yfinance_1m_data"
output_dir = "yfinance_1m_data_cleaned"
os.makedirs(output_dir, exist_ok=True)

for filename in os.listdir(input_dir):
    if filename.endswith(".csv"):
        input_path = os.path.join(input_dir, filename)
        output_path = os.path.join(output_dir, filename)

        try:

            df = pd.read_csv(input_path, skiprows=[1,2])


            df.rename(columns={df.columns[0]: 'Datetime'}, inplace=True)

            df.to_csv(output_path, index=False)

            print(f"Processed {filename}: removed second row and renamed first column to 'Datetime'. Saved to {output_dir}.")

        except Exception as e:
            print(f"Error processing {filename}: {e}")

print("All files processed.")
# Out:
# Processed GOOG.csv: removed second row and renamed first column to 'Datetime'. Saved to yfinance_1m_data_cleaned.
# Processed ABBV.csv: removed second row and renamed first column to 'Datetime'. Saved to yfinance_1m_data_cleaned.
# Processed JNJ.csv: removed second row and renamed first column to 'Datetime'. Saved to yfinance_1m_data_cleaned.
# Processed AMZN.csv: removed second row and renamed first column to 'Datetime'. Saved to yfinance_1m_data_cleaned.
# Processed COST.csv: removed second row and renamed first column to 'Datetime'. Saved to yfinance_1m_data_cleaned.
# Processed HD.csv: removed second row and renamed first column to 'Datetime'. Saved to yfinance_1m_data_cleaned.
# Processed PG.csv: removed second row and renamed first column to 'Datetime'. Saved to yfinance_1m_data_cleaned.
# Processed V.csv: removed second row and renamed first column to 'Datetime'. Saved to yfinance_1m_data_cleaned.
# Processed SPY.csv: removed second row and renamed first column to 'Datetime'. Saved to yfinance_1m_data_cleaned.
# Processed JPM.csv: removed second row and renamed first column to 'Datetime'. Saved to yfinance_1m_data_cleaned.
# Processed META.csv: removed second row and renamed first column to 'Datetime'. Saved to yfinance_1m_data_cleaned.
# Processed CVX.csv: removed second row and renamed first column to 'Datetime'. Saved to yfinance_1m_data_cleaned.
# Processed MSFT.csv: removed second row and renamed first column to 'Datetime'. Saved to yfinance_1m_data_cleaned.
# Processed NVDA.csv: removed second row and renamed first column to 'Datetime'. Saved to yfinance_1m_data_cleaned.
# Processed AAPL.csv: removed second row and renamed first column to 'Datetime'. Saved to yfinance_1m_data_cleaned.
# Processed UNH.csv: removed second row and renamed first column to 'Datetime'. Saved to yfinance_1m_data_cleaned.
# Processed XOM.csv: removed second row and renamed first column to 'Datetime'. Saved to yfinance_1m_data_cleaned.
# Processed MRK.csv: removed second row and renamed first column to 'Datetime'. Saved to yfinance_1m_data_cleaned.
# Processed PEP.csv: removed second row and renamed first column to 'Datetime'. Saved to yfinance_1m_data_cleaned.
# All files processed.

# %%
import pandas as pd
import os
from datetime import datetime
import pytz

input_dir = "yfinance_1m_data_cleaned"

output_dir = "percent_changes"
os.makedirs(output_dir, exist_ok=True)

tickers = [
    "GOOG", "MSFT", "BRK-B", "AAPL", "AMZN", "JPM", "JNJ",
    "NVDA", "XOM", "V", "PG", "META", "HD", "SPY", "CVX",
    "MRK", "PEP", "ABBV", "UNH", "COST"
]

exceptions = ["BRK-B"]

processed_tickers = [
    ticker.replace('-', '.') if ticker not in exceptions else ticker
    for ticker in tickers
]

# Defining Intervals for change to be observed
intervals = [
    ("09:30", "10:00"),
    ("10:00", "10:30"),
    ("10:30", "11:00"),
    ("11:00", "11:30"),
    ("11:30", "12:00"),
    ("12:00", "12:30"),
    ("12:30", "13:00"),
    ("13:00", "13:30"),
    ("13:30", "14:00"),
    ("14:00", "14:30"),
    ("14:30", "15:00"),
    ("15:00", "15:30"),
    ("15:30", "16:00")
]


# Timezone Clarification
UTC = pytz.utc
ET = pytz.timezone('US/Eastern')

def calculate_percent_changes(ticker, input_dir, output_dir, intervals):

    input_file = os.path.join(input_dir, f"{ticker}.csv")
    if not os.path.exists(input_file):
        print(f"CSV file for {ticker} not found in '{input_dir}'. Skipping.\n")
        return

    try:
        df = pd.read_csv(
            input_file,
            parse_dates=['Datetime'],
            index_col='Datetime'
        )
        print(f"Successfully read CSV for {ticker}.")
    except Exception as e:
        print(f"Error reading '{input_file}': {e}\n")
        return

    if df.index.tzinfo is None or df.index.tz is None:
        try:
            df.index = df.index.tz_localize(UTC)
            print(f"Localized timezone for {ticker} to UTC.")
        except Exception as e:
            print(f"Error localizing timezone for {ticker}: {e}\n")
            return

    try:
        df.index = df.index.tz_convert(ET)
        print(f"Converted timezone for {ticker} to Eastern Time.")
    except Exception as e:
        print(f"Error converting timezone for {ticker}: {e}\n")
        return

    # Sort by datetime
    df.sort_index(inplace=True)

    # Add date column
    df['Date'] = df.index.date

    # Initialize a list for percent changes
    records = []

    unique_dates = sorted(df['Date'].unique())

    for i in range(1, len(unique_dates)):
        current_date = unique_dates[i]
        previous_date = unique_dates[i - 1]

        # Get the close price at 16:00 ET
        prev_day_data = df[df['Date'] == previous_date]
        try:
            # Get the last available close before or at 16:00
            prev_close_df = prev_day_data.between_time('15:59', '16:00')
            if prev_close_df.empty:
                print(f"No close data for {ticker} on {previous_date} at 16:00. Skipping overnight change for {current_date}.\n")
                prev_close_price = None
            else:
                prev_close_time = prev_close_df.iloc[-1]
                if 'Close' not in prev_close_time:
                    print(f"'Close' column missing for {ticker} on {previous_date} at 16:00. Skipping overnight change for {current_date}.\n")
                    prev_close_price = None
                else:
                    prev_close_price = prev_close_time['Close']
                    print(f"Previous close for {ticker} on {previous_date} is {prev_close_price}.")
        except Exception as e:
            print(f"Error retrieving previous close for {ticker} on {previous_date}: {e}\n")
            prev_close_price = None

        current_day_data = df[df['Date'] == current_date]

        try:
            open_price_df = current_day_data.between_time('09:30', '09:30')
            if open_price_df.empty:
                print(f"Open price at 09:30 for {ticker} on {current_date} not found. Skipping overnight change.\n")
                continue
            open_price = open_price_df.iloc[0]['Open']
            print(f"Open price for {ticker} on {current_date} at 09:30 is {open_price}.")
        except Exception as e:
            print(f"Error retrieving open price for {ticker} on {current_date} at 09:30: {e}\n")
            continue

        # Calculate Overnight Change (Previous Close to Open)
        if prev_close_price is not None:
            overnight_change = ((open_price - prev_close_price) / prev_close_price) * 100
            records.append({
                "Date": current_date,
                "Interval": "Overnight (16:00 Prev Close to 09:30 Open)",
                "Percent Change": overnight_change
            })
            print(f"Overnight change for {ticker} on {current_date}: {overnight_change:.4f}%")

        for start_time, end_time in intervals:
            try:
                start_dt_naive = datetime.combine(current_date, datetime.strptime(start_time, "%H:%M").time())
                end_dt_naive = datetime.combine(current_date, datetime.strptime(end_time, "%H:%M").time())

                # Eastern Time Adjustment
                start_dt = ET.localize(start_dt_naive)
                end_dt = ET.localize(end_dt_naive)

                if start_dt not in current_day_data.index or end_dt not in current_day_data.index:
                    print(f"Missing data for {ticker} on {current_date} during interval {start_time} to {end_time}. Skipping this interval.\n")
                    continue

                # Open price at start_time
                start_price = current_day_data.loc[start_dt]['Open']

                # Get the close price at end_time
                end_price = current_day_data.loc[end_dt]['Close']

                # Calculate percent change
                percent_change = ((end_price - start_price) / start_price) * 100

                # Define interval label
                interval_label = f"{start_time} to {end_time}"

                # Append to records
                records.append({
                    "Date": current_date,
                    "Interval": interval_label,
                    "Percent Change": percent_change
                })
                print(f"Percent change for {ticker} on {current_date} during {interval_label}: {percent_change:.4f}%")
            except KeyError as ke:
                print(f"KeyError for {ticker} on {current_date} during interval {start_time} to {end_time}: {ke}. Skipping this interval.\n")
                continue
            except Exception as e:
                print(f"Error processing interval {start_time} to {end_time} for {ticker} on {current_date}: {e}\n")
                continue

        if records:
            percent_changes_df = pd.DataFrame(records)

            output_file = os.path.join(output_dir, f"{ticker}.csv")

            # Save to CSV
            try:
                percent_changes_df.to_csv(output_file, index=False)
                print(f"Processed percent changes for {ticker} saved to '{output_file}'.\n")
            except Exception as e:
                print(f"Error saving percent changes for {ticker} to '{output_file}': {e}\n")
        else:
            print(f"No percent change records generated for {ticker}.\n")

def main():

    for original_ticker, processed_ticker in zip(tickers, processed_tickers):
        print(f"Processing ticker: {processed_ticker}")
        calculate_percent_changes(processed_ticker, input_dir, output_dir, intervals)
    print("All tickers processed.")

if __name__ == "__main__":
    main()
# Out:
# Processing ticker: GOOG
# Successfully read CSV for GOOG.
# Converted timezone for GOOG to Eastern Time.
# Previous close for GOOG on 2025-01-22 is 199.9900054931641.
# Open price for GOOG on 2025-01-23 at 09:30 is 199.97000122070312.
# Overnight change for GOOG on 2025-01-23: -0.0100%
# Percent change for GOOG on 2025-01-23 during 09:30 to 10:00: 0.0450%
# Percent change for GOOG on 2025-01-23 during 10:00 to 10:30: 0.2246%
# Percent change for GOOG on 2025-01-23 during 10:30 to 11:00: 0.4162%
# Percent change for GOOG on 2025-01-23 during 11:00 to 11:30: 0.1806%
# Percent change for GOOG on 2025-01-23 during 11:30 to 12:00: -0.2724%
# Percent change for GOOG on 2025-01-23 during 12:00 to 12:30: -0.2507%
# Percent change for GOOG on 2025-01-23 during 12:30 to 13:00: -0.0498%
# Percent change for GOOG on 2025-01-23 during 13:00 to 13:30: -0.1542%
# Percent change for GOOG on 2025-01-23 during 13:30 to 14:00: -1.1308%
# Percent change for GOOG on 2025-01-23 during 14:00 to 14:30: -0.0677%
# Percent change for GOOG on 2025-01-23 during 14:30 to 15:00: 0.3183%
# Percent change for GOOG on 2025-01-23 during 15:00 to 15:30: 0.1864%
# Missing data for GOOG on 2025-01-23 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for GOOG saved to 'percent_changes/GOOG.csv'.
#
# Previous close for GOOG on 2025-01-23 is 199.58999633789065.
# Open price for GOOG on 2025-01-24 at 09:30 is 199.8699951171875.
# Overnight change for GOOG on 2025-01-24: 0.1403%
# Percent change for GOOG on 2025-01-24 during 09:30 to 10:00: 0.6604%
# Percent change for GOOG on 2025-01-24 during 10:00 to 10:30: -0.3030%
# Percent change for GOOG on 2025-01-24 during 10:30 to 11:00: -0.0901%
# Percent change for GOOG on 2025-01-24 during 11:00 to 11:30: 0.3824%
# Percent change for GOOG on 2025-01-24 during 11:30 to 12:00: -0.0646%
# Percent change for GOOG on 2025-01-24 during 12:00 to 12:30: 0.0149%
# Percent change for GOOG on 2025-01-24 during 12:30 to 13:00: 0.2637%
# Percent change for GOOG on 2025-01-24 during 13:00 to 13:30: 0.0496%
# Percent change for GOOG on 2025-01-24 during 13:30 to 14:00: 0.0397%
# Percent change for GOOG on 2025-01-24 during 14:00 to 14:30: 0.3273%
# Percent change for GOOG on 2025-01-24 during 14:30 to 15:00: -0.2866%
# Percent change for GOOG on 2025-01-24 during 15:00 to 15:30: -0.0644%
# Missing data for GOOG on 2025-01-24 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for GOOG saved to 'percent_changes/GOOG.csv'.
#
# Previous close for GOOG on 2025-01-24 is 201.9199981689453.
# Open price for GOOG on 2025-01-27 at 09:30 is 194.19000244140625.
# Overnight change for GOOG on 2025-01-27: -3.8282%
# Percent change for GOOG on 2025-01-27 during 09:30 to 10:00: 0.9372%
# Percent change for GOOG on 2025-01-27 during 10:00 to 10:30: 0.5150%
# Percent change for GOOG on 2025-01-27 during 10:30 to 11:00: 0.1581%
# Percent change for GOOG on 2025-01-27 during 11:00 to 11:30: -0.6072%
# Percent change for GOOG on 2025-01-27 during 11:30 to 12:00: -0.2367%
# Percent change for GOOG on 2025-01-27 during 12:00 to 12:30: 0.0614%
# Percent change for GOOG on 2025-01-27 during 12:30 to 13:00: -0.2555%
# Percent change for GOOG on 2025-01-27 during 13:00 to 13:30: -0.0921%
# Percent change for GOOG on 2025-01-27 during 13:30 to 14:00: -0.0871%
# Percent change for GOOG on 2025-01-27 during 14:00 to 14:30: 0.2051%
# Percent change for GOOG on 2025-01-27 during 14:30 to 15:00: -1.1291%
# Percent change for GOOG on 2025-01-27 during 15:00 to 15:30: -0.1788%
# Missing data for GOOG on 2025-01-27 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for GOOG saved to 'percent_changes/GOOG.csv'.
#
# Previous close for GOOG on 2025-01-27 is 193.759994506836.
# Open price for GOOG on 2025-01-28 at 09:30 is 194.13009643554688.
# Overnight change for GOOG on 2025-01-28: 0.1910%
# Percent change for GOOG on 2025-01-28 during 09:30 to 10:00: 0.1081%
# Percent change for GOOG on 2025-01-28 during 10:00 to 10:30: 1.0202%
# Percent change for GOOG on 2025-01-28 during 10:30 to 11:00: 0.3261%
# Percent change for GOOG on 2025-01-28 during 11:00 to 11:30: -0.4052%
# Percent change for GOOG on 2025-01-28 during 11:30 to 12:00: 0.2089%
# Percent change for GOOG on 2025-01-28 during 12:00 to 12:30: 0.0967%
# Percent change for GOOG on 2025-01-28 during 12:30 to 13:00: -0.0619%
# Percent change for GOOG on 2025-01-28 during 13:00 to 13:30: 0.0254%
# Percent change for GOOG on 2025-01-28 during 13:30 to 14:00: 0.0534%
# Percent change for GOOG on 2025-01-28 during 14:00 to 14:30: -0.0305%
# Percent change for GOOG on 2025-01-28 during 14:30 to 15:00: -0.0203%
# Percent change for GOOG on 2025-01-28 during 15:00 to 15:30: 0.2137%
# Missing data for GOOG on 2025-01-28 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for GOOG saved to 'percent_changes/GOOG.csv'.
#
# Previous close for GOOG on 2025-01-28 is 197.009994506836.
# Open price for GOOG on 2025-01-29 at 09:30 is 197.3600006103516.
# Overnight change for GOOG on 2025-01-29: 0.1777%
# Percent change for GOOG on 2025-01-29 during 09:30 to 10:00: -0.8766%
# Percent change for GOOG on 2025-01-29 during 10:00 to 10:30: 0.1533%
# Percent change for GOOG on 2025-01-29 during 10:30 to 11:00: 0.3576%
# Percent change for GOOG on 2025-01-29 during 11:00 to 11:30: 0.0153%
# Percent change for GOOG on 2025-01-29 during 11:30 to 12:00: 0.1577%
# Percent change for GOOG on 2025-01-29 during 12:00 to 12:30: 0.0813%
# Percent change for GOOG on 2025-01-29 during 12:30 to 13:00: -0.0711%
# Percent change for GOOG on 2025-01-29 during 13:00 to 13:30: 0.0829%
# Percent change for GOOG on 2025-01-29 during 13:30 to 14:00: -0.1143%
# Percent change for GOOG on 2025-01-29 during 14:00 to 14:30: 0.1525%
# Percent change for GOOG on 2025-01-29 during 14:30 to 15:00: 0.5078%
# Percent change for GOOG on 2025-01-29 during 15:00 to 15:30: 0.0960%
# Missing data for GOOG on 2025-01-29 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for GOOG saved to 'percent_changes/GOOG.csv'.
#
# Previous close for GOOG on 2025-01-29 is 197.1499938964844.
# Open price for GOOG on 2025-01-30 at 09:30 is 199.759994506836.
# Overnight change for GOOG on 2025-01-30: 1.3239%
# Percent change for GOOG on 2025-01-30 during 09:30 to 10:00: 1.1714%
# Percent change for GOOG on 2025-01-30 during 10:00 to 10:30: -0.4651%
# Percent change for GOOG on 2025-01-30 during 10:30 to 11:00: -0.8681%
# Percent change for GOOG on 2025-01-30 during 11:00 to 11:30: 0.8689%
# Percent change for GOOG on 2025-01-30 during 11:30 to 12:00: 0.1689%
# Percent change for GOOG on 2025-01-30 during 12:00 to 12:30: -0.4186%
# Percent change for GOOG on 2025-01-30 during 12:30 to 13:00: 0.0675%
# Percent change for GOOG on 2025-01-30 during 13:00 to 13:30: 0.1864%
# Percent change for GOOG on 2025-01-30 during 13:30 to 14:00: 0.3400%
# Percent change for GOOG on 2025-01-30 during 14:00 to 14:30: -0.0989%
# Percent change for GOOG on 2025-01-30 during 14:30 to 15:00: 0.1916%
# Percent change for GOOG on 2025-01-30 during 15:00 to 15:30: 0.1829%
# Missing data for GOOG on 2025-01-30 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for GOOG saved to 'percent_changes/GOOG.csv'.
#
# Processing ticker: MSFT
# Successfully read CSV for MSFT.
# Converted timezone for MSFT to Eastern Time.
# Previous close for MSFT on 2025-01-22 is 446.1600036621094.
# Open price for MSFT on 2025-01-23 at 09:30 is 442.0.
# Overnight change for MSFT on 2025-01-23: -0.9324%
# Percent change for MSFT on 2025-01-23 during 09:30 to 10:00: 0.3620%
# Percent change for MSFT on 2025-01-23 during 10:00 to 10:30: -0.1093%
# Percent change for MSFT on 2025-01-23 during 10:30 to 11:00: -0.1060%
# Percent change for MSFT on 2025-01-23 during 11:00 to 11:30: 0.1377%
# Percent change for MSFT on 2025-01-23 during 11:30 to 12:00: -0.0912%
# Percent change for MSFT on 2025-01-23 during 12:00 to 12:30: -0.1330%
# Percent change for MSFT on 2025-01-23 during 12:30 to 13:00: -0.0711%
# Percent change for MSFT on 2025-01-23 during 13:00 to 13:30: 0.1014%
# Percent change for MSFT on 2025-01-23 during 13:30 to 14:00: 0.1692%
# Percent change for MSFT on 2025-01-23 during 14:00 to 14:30: 0.1214%
# Percent change for MSFT on 2025-01-23 during 14:30 to 15:00: 0.2690%
# Percent change for MSFT on 2025-01-23 during 15:00 to 15:30: -0.0427%
# Missing data for MSFT on 2025-01-23 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for MSFT saved to 'percent_changes/MSFT.csv'.
#
# Previous close for MSFT on 2025-01-23 is 446.7000122070313.
# Open price for MSFT on 2025-01-24 at 09:30 is 445.1600036621094.
# Overnight change for MSFT on 2025-01-24: -0.3448%
# Percent change for MSFT on 2025-01-24 during 09:30 to 10:00: -0.1314%
# Percent change for MSFT on 2025-01-24 during 10:00 to 10:30: -0.1124%
# Percent change for MSFT on 2025-01-24 during 10:30 to 11:00: 0.3713%
# Percent change for MSFT on 2025-01-24 during 11:00 to 11:30: 0.2674%
# Percent change for MSFT on 2025-01-24 during 11:30 to 12:00: -0.1512%
# Percent change for MSFT on 2025-01-24 during 12:00 to 12:30: -0.2149%
# Percent change for MSFT on 2025-01-24 during 12:30 to 13:00: -0.1671%
# Percent change for MSFT on 2025-01-24 during 13:00 to 13:30: -0.0349%
# Percent change for MSFT on 2025-01-24 during 13:30 to 14:00: -0.3649%
# Percent change for MSFT on 2025-01-24 during 14:00 to 14:30: 0.0586%
# Percent change for MSFT on 2025-01-24 during 14:30 to 15:00: -0.0396%
# Percent change for MSFT on 2025-01-24 during 15:00 to 15:30: 0.1425%
# Missing data for MSFT on 2025-01-24 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for MSFT saved to 'percent_changes/MSFT.csv'.
#
# Previous close for MSFT on 2025-01-24 is 443.9800109863281.
# Open price for MSFT on 2025-01-27 at 09:30 is 424.2099914550781.
# Overnight change for MSFT on 2025-01-27: -4.4529%
# Percent change for MSFT on 2025-01-27 during 09:30 to 10:00: 1.1657%
# Percent change for MSFT on 2025-01-27 during 10:00 to 10:30: 0.3862%
# Percent change for MSFT on 2025-01-27 during 10:30 to 11:00: -0.3804%
# Percent change for MSFT on 2025-01-27 during 11:00 to 11:30: -0.4646%
# Percent change for MSFT on 2025-01-27 during 11:30 to 12:00: 0.1299%
# Percent change for MSFT on 2025-01-27 during 12:00 to 12:30: -0.1173%
# Percent change for MSFT on 2025-01-27 during 12:30 to 13:00: 0.1989%
# Percent change for MSFT on 2025-01-27 during 13:00 to 13:30: 0.3773%
# Percent change for MSFT on 2025-01-27 during 13:30 to 14:00: 0.5613%
# Percent change for MSFT on 2025-01-27 during 14:00 to 14:30: 0.5250%
# Percent change for MSFT on 2025-01-27 during 14:30 to 15:00: -0.2774%
# Percent change for MSFT on 2025-01-27 during 15:00 to 15:30: 0.3372%
# Missing data for MSFT on 2025-01-27 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for MSFT saved to 'percent_changes/MSFT.csv'.
#
# Previous close for MSFT on 2025-01-27 is 434.5700073242188.
# Open price for MSFT on 2025-01-28 at 09:30 is 432.7999877929688.
# Overnight change for MSFT on 2025-01-28: -0.4073%
# Percent change for MSFT on 2025-01-28 during 09:30 to 10:00: 0.5987%
# Percent change for MSFT on 2025-01-28 during 10:00 to 10:30: 1.6624%
# Percent change for MSFT on 2025-01-28 during 10:30 to 11:00: -0.2066%
# Percent change for MSFT on 2025-01-28 during 11:00 to 11:30: 0.1234%
# Percent change for MSFT on 2025-01-28 during 11:30 to 12:00: 0.2964%
# Percent change for MSFT on 2025-01-28 during 12:00 to 12:30: 0.3001%
# Percent change for MSFT on 2025-01-28 during 12:30 to 13:00: 0.1091%
# Percent change for MSFT on 2025-01-28 during 13:00 to 13:30: 0.2404%
# Percent change for MSFT on 2025-01-28 during 13:30 to 14:00: -0.1210%
# Percent change for MSFT on 2025-01-28 during 14:00 to 14:30: 0.2844%
# Percent change for MSFT on 2025-01-28 during 14:30 to 15:00: 0.2921%
# Percent change for MSFT on 2025-01-28 during 15:00 to 15:30: -0.3148%
# Missing data for MSFT on 2025-01-28 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for MSFT saved to 'percent_changes/MSFT.csv'.
#
# Previous close for MSFT on 2025-01-28 is 447.0199890136719.
# Open price for MSFT on 2025-01-29 at 09:30 is 446.6900024414063.
# Overnight change for MSFT on 2025-01-29: -0.0738%
# Percent change for MSFT on 2025-01-29 during 09:30 to 10:00: -1.1193%
# Percent change for MSFT on 2025-01-29 during 10:00 to 10:30: 0.1642%
# Percent change for MSFT on 2025-01-29 during 10:30 to 11:00: 0.1109%
# Percent change for MSFT on 2025-01-29 during 11:00 to 11:30: -0.0520%
# Percent change for MSFT on 2025-01-29 during 11:30 to 12:00: 0.3748%
# Percent change for MSFT on 2025-01-29 during 12:00 to 12:30: -0.0620%
# Percent change for MSFT on 2025-01-29 during 12:30 to 13:00: -0.1411%
# Percent change for MSFT on 2025-01-29 during 13:00 to 13:30: 0.0045%
# Percent change for MSFT on 2025-01-29 during 13:30 to 14:00: -0.3396%
# Percent change for MSFT on 2025-01-29 during 14:00 to 14:30: -0.0497%
# Percent change for MSFT on 2025-01-29 during 14:30 to 15:00: 0.6616%
# Percent change for MSFT on 2025-01-29 during 15:00 to 15:30: 0.0315%
# Missing data for MSFT on 2025-01-29 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for MSFT saved to 'percent_changes/MSFT.csv'.
#
# Previous close for MSFT on 2025-01-29 is 441.7900085449219.
# Open price for MSFT on 2025-01-30 at 09:30 is 418.4800109863281.
# Overnight change for MSFT on 2025-01-30: -5.2763%
# Percent change for MSFT on 2025-01-30 during 09:30 to 10:00: 0.4230%
# Percent change for MSFT on 2025-01-30 during 10:00 to 10:30: -1.8022%
# Percent change for MSFT on 2025-01-30 during 10:30 to 11:00: 0.0144%
# Percent change for MSFT on 2025-01-30 during 11:00 to 11:30: 0.0385%
# Percent change for MSFT on 2025-01-30 during 11:30 to 12:00: 0.0638%
# Percent change for MSFT on 2025-01-30 during 12:00 to 12:30: -0.4684%
# Percent change for MSFT on 2025-01-30 during 12:30 to 13:00: 0.0350%
# Percent change for MSFT on 2025-01-30 during 13:00 to 13:30: 0.3607%
# Percent change for MSFT on 2025-01-30 during 13:30 to 14:00: -0.1299%
# Percent change for MSFT on 2025-01-30 during 14:00 to 14:30: 0.0675%
# Percent change for MSFT on 2025-01-30 during 14:30 to 15:00: 0.1361%
# Percent change for MSFT on 2025-01-30 during 15:00 to 15:30: 0.0313%
# Missing data for MSFT on 2025-01-30 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for MSFT saved to 'percent_changes/MSFT.csv'.
#
# Processing ticker: BRK-B
# CSV file for BRK-B not found in 'yfinance_1m_data_cleaned'. Skipping.
#
# Processing ticker: AAPL
# Successfully read CSV for AAPL.
# Converted timezone for AAPL to Eastern Time.
# Previous close for AAPL on 2025-01-22 is 223.7700042724609.
# Open price for AAPL on 2025-01-23 at 09:30 is 224.72999572753903.
# Overnight change for AAPL on 2025-01-23: 0.4290%
# Percent change for AAPL on 2025-01-23 during 09:30 to 10:00: 0.1446%
# Percent change for AAPL on 2025-01-23 during 10:00 to 10:30: 0.3997%
# Percent change for AAPL on 2025-01-23 during 10:30 to 11:00: -0.3076%
# Percent change for AAPL on 2025-01-23 during 11:00 to 11:30: -0.1081%
# Percent change for AAPL on 2025-01-23 during 11:30 to 12:00: -0.5063%
# Percent change for AAPL on 2025-01-23 during 12:00 to 12:30: -0.2633%
# Percent change for AAPL on 2025-01-23 during 12:30 to 13:00: 0.0738%
# Percent change for AAPL on 2025-01-23 during 13:00 to 13:30: -0.0358%
# Percent change for AAPL on 2025-01-23 during 13:30 to 14:00: -0.2348%
# Percent change for AAPL on 2025-01-23 during 14:00 to 14:30: -0.0964%
# Percent change for AAPL on 2025-01-23 during 14:30 to 15:00: -0.0224%
# Percent change for AAPL on 2025-01-23 during 15:00 to 15:30: 0.0763%
# Missing data for AAPL on 2025-01-23 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for AAPL saved to 'percent_changes/AAPL.csv'.
#
# Previous close for AAPL on 2025-01-23 is 223.6499938964844.
# Open price for AAPL on 2025-01-24 at 09:30 is 224.9750061035156.
# Overnight change for AAPL on 2025-01-24: 0.5924%
# Percent change for AAPL on 2025-01-24 during 09:30 to 10:00: -0.3089%
# Percent change for AAPL on 2025-01-24 during 10:00 to 10:30: -0.7593%
# Percent change for AAPL on 2025-01-24 during 10:30 to 11:00: 0.1190%
# Percent change for AAPL on 2025-01-24 during 11:00 to 11:30: -0.1083%
# Percent change for AAPL on 2025-01-24 during 11:30 to 12:00: -0.0269%
# Percent change for AAPL on 2025-01-24 during 12:00 to 12:30: -0.2334%
# Percent change for AAPL on 2025-01-24 during 12:30 to 13:00: 0.0360%
# Percent change for AAPL on 2025-01-24 during 13:00 to 13:30: -0.0989%
# Percent change for AAPL on 2025-01-24 during 13:30 to 14:00: -0.0315%
# Percent change for AAPL on 2025-01-24 during 14:00 to 14:30: 0.1464%
# Percent change for AAPL on 2025-01-24 during 14:30 to 15:00: 0.0854%
# Percent change for AAPL on 2025-01-24 during 15:00 to 15:30: -0.0749%
# Missing data for AAPL on 2025-01-24 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for AAPL saved to 'percent_changes/AAPL.csv'.
#
# Previous close for AAPL on 2025-01-24 is 222.7899932861328.
# Open price for AAPL on 2025-01-27 at 09:30 is 224.02999877929688.
# Overnight change for AAPL on 2025-01-27: 0.5566%
# Percent change for AAPL on 2025-01-27 during 09:30 to 10:00: 0.5571%
# Percent change for AAPL on 2025-01-27 during 10:00 to 10:30: 0.7445%
# Percent change for AAPL on 2025-01-27 during 10:30 to 11:00: 0.1864%
# Percent change for AAPL on 2025-01-27 during 11:00 to 11:30: 0.2722%
# Percent change for AAPL on 2025-01-27 during 11:30 to 12:00: 0.0173%
# Percent change for AAPL on 2025-01-27 during 12:00 to 12:30: 0.7064%
# Percent change for AAPL on 2025-01-27 during 12:30 to 13:00: 0.0456%
# Percent change for AAPL on 2025-01-27 during 13:00 to 13:30: 0.5583%
# Percent change for AAPL on 2025-01-27 during 13:30 to 14:00: 0.0130%
# Percent change for AAPL on 2025-01-27 during 14:00 to 14:30: 0.1560%
# Percent change for AAPL on 2025-01-27 during 14:30 to 15:00: -0.1896%
# Percent change for AAPL on 2025-01-27 during 15:00 to 15:30: -0.3929%
# Missing data for AAPL on 2025-01-27 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for AAPL saved to 'percent_changes/AAPL.csv'.
#
# Previous close for AAPL on 2025-01-27 is 229.94000244140625.
# Open price for AAPL on 2025-01-28 at 09:30 is 230.8800048828125.
# Overnight change for AAPL on 2025-01-28: 0.4088%
# Percent change for AAPL on 2025-01-28 during 09:30 to 10:00: 1.7005%
# Percent change for AAPL on 2025-01-28 during 10:00 to 10:30: 1.4169%
# Percent change for AAPL on 2025-01-28 during 10:30 to 11:00: 0.4166%
# Percent change for AAPL on 2025-01-28 during 11:00 to 11:30: 0.2387%
# Percent change for AAPL on 2025-01-28 during 11:30 to 12:00: 0.2614%
# Percent change for AAPL on 2025-01-28 during 12:00 to 12:30: -0.4443%
# Percent change for AAPL on 2025-01-28 during 12:30 to 13:00: 0.1090%
# Percent change for AAPL on 2025-01-28 during 13:00 to 13:30: 0.0251%
# Percent change for AAPL on 2025-01-28 during 13:30 to 14:00: 0.0260%
# Percent change for AAPL on 2025-01-28 during 14:00 to 14:30: 0.0544%
# Percent change for AAPL on 2025-01-28 during 14:30 to 15:00: 0.1012%
# Percent change for AAPL on 2025-01-28 during 15:00 to 15:30: -0.1443%
# Missing data for AAPL on 2025-01-28 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for AAPL saved to 'percent_changes/AAPL.csv'.
#
# Previous close for AAPL on 2025-01-28 is 238.2400054931641.
# Open price for AAPL on 2025-01-29 at 09:30 is 235.0.
# Overnight change for AAPL on 2025-01-29: -1.3600%
# Percent change for AAPL on 2025-01-29 during 09:30 to 10:00: 0.3468%
# Percent change for AAPL on 2025-01-29 during 10:00 to 10:30: 0.5333%
# Percent change for AAPL on 2025-01-29 during 10:30 to 11:00: 0.4004%
# Percent change for AAPL on 2025-01-29 during 11:00 to 11:30: -0.4963%
# Percent change for AAPL on 2025-01-29 during 11:30 to 12:00: -0.0042%
# Percent change for AAPL on 2025-01-29 during 12:00 to 12:30: 0.1268%
# Percent change for AAPL on 2025-01-29 during 12:30 to 13:00: -0.3588%
# Percent change for AAPL on 2025-01-29 during 13:00 to 13:30: 0.6270%
# Percent change for AAPL on 2025-01-29 during 13:30 to 14:00: -0.3285%
# Percent change for AAPL on 2025-01-29 during 14:00 to 14:30: -0.1601%
# Percent change for AAPL on 2025-01-29 during 14:30 to 15:00: 0.7129%
# Percent change for AAPL on 2025-01-29 during 15:00 to 15:30: 0.3906%
# Missing data for AAPL on 2025-01-29 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for AAPL saved to 'percent_changes/AAPL.csv'.
#
# Previous close for AAPL on 2025-01-29 is 239.3500061035156.
# Open price for AAPL on 2025-01-30 at 09:30 is 238.6649932861328.
# Overnight change for AAPL on 2025-01-30: -0.2862%
# Percent change for AAPL on 2025-01-30 during 09:30 to 10:00: 0.1697%
# Percent change for AAPL on 2025-01-30 during 10:00 to 10:30: -0.4344%
# Percent change for AAPL on 2025-01-30 during 10:30 to 11:00: -0.1027%
# Percent change for AAPL on 2025-01-30 during 11:00 to 11:30: 0.1029%
# Percent change for AAPL on 2025-01-30 during 11:30 to 12:00: 0.2794%
# Percent change for AAPL on 2025-01-30 during 12:00 to 12:30: -0.3225%
# Percent change for AAPL on 2025-01-30 during 12:30 to 13:00: 0.1827%
# Percent change for AAPL on 2025-01-30 during 13:00 to 13:30: 0.0378%
# Percent change for AAPL on 2025-01-30 during 13:30 to 14:00: 0.4739%
# Percent change for AAPL on 2025-01-30 during 14:00 to 14:30: -0.1331%
# Percent change for AAPL on 2025-01-30 during 14:30 to 15:00: 0.2480%
# Percent change for AAPL on 2025-01-30 during 15:00 to 15:30: -0.0938%
# Missing data for AAPL on 2025-01-30 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for AAPL saved to 'percent_changes/AAPL.csv'.
#
# Processing ticker: AMZN
# Successfully read CSV for AMZN.
# Converted timezone for AMZN to Eastern Time.
# Previous close for AMZN on 2025-01-22 is 235.009994506836.
# Open price for AMZN on 2025-01-23 at 09:30 is 234.0.
# Overnight change for AMZN on 2025-01-23: -0.4298%
# Percent change for AMZN on 2025-01-23 during 09:30 to 10:00: -0.1880%
# Percent change for AMZN on 2025-01-23 during 10:00 to 10:30: 0.4460%
# Percent change for AMZN on 2025-01-23 during 10:30 to 11:00: -0.0213%
# Percent change for AMZN on 2025-01-23 during 11:00 to 11:30: 0.0256%
# Percent change for AMZN on 2025-01-23 during 11:30 to 12:00: -0.2389%
# Percent change for AMZN on 2025-01-23 during 12:00 to 12:30: -0.2813%
# Percent change for AMZN on 2025-01-23 during 12:30 to 13:00: 0.0581%
# Percent change for AMZN on 2025-01-23 during 13:00 to 13:30: 0.0458%
# Percent change for AMZN on 2025-01-23 during 13:30 to 14:00: 0.0257%
# Percent change for AMZN on 2025-01-23 during 14:00 to 14:30: -0.0428%
# Percent change for AMZN on 2025-01-23 during 14:30 to 15:00: 0.1413%
# Percent change for AMZN on 2025-01-23 during 15:00 to 15:30: 0.1817%
# Missing data for AMZN on 2025-01-23 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for AMZN saved to 'percent_changes/AMZN.csv'.
#
# Previous close for AMZN on 2025-01-23 is 235.3999938964844.
# Open price for AMZN on 2025-01-24 at 09:30 is 234.97000122070312.
# Overnight change for AMZN on 2025-01-24: -0.1827%
# Percent change for AMZN on 2025-01-24 during 09:30 to 10:00: 0.4937%
# Percent change for AMZN on 2025-01-24 during 10:00 to 10:30: -0.4660%
# Percent change for AMZN on 2025-01-24 during 10:30 to 11:00: -0.1194%
# Percent change for AMZN on 2025-01-24 during 11:00 to 11:30: 0.1537%
# Percent change for AMZN on 2025-01-24 during 11:30 to 12:00: -0.2346%
# Percent change for AMZN on 2025-01-24 during 12:00 to 12:30: -0.0150%
# Percent change for AMZN on 2025-01-24 during 12:30 to 13:00: -0.0150%
# Percent change for AMZN on 2025-01-24 during 13:00 to 13:30: 0.0826%
# Percent change for AMZN on 2025-01-24 during 13:30 to 14:00: -0.1794%
# Percent change for AMZN on 2025-01-24 during 14:00 to 14:30: -0.0257%
# Percent change for AMZN on 2025-01-24 during 14:30 to 15:00: -0.0685%
# Percent change for AMZN on 2025-01-24 during 15:00 to 15:30: 0.1930%
# Missing data for AMZN on 2025-01-24 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for AMZN saved to 'percent_changes/AMZN.csv'.
#
# Previous close for AMZN on 2025-01-24 is 234.8500061035156.
# Open price for AMZN on 2025-01-27 at 09:30 is 226.2700042724609.
# Overnight change for AMZN on 2025-01-27: -3.6534%
# Percent change for AMZN on 2025-01-27 during 09:30 to 10:00: 1.5468%
# Percent change for AMZN on 2025-01-27 during 10:00 to 10:30: 1.1019%
# Percent change for AMZN on 2025-01-27 during 10:30 to 11:00: 0.0625%
# Percent change for AMZN on 2025-01-27 during 11:00 to 11:30: -0.0817%
# Percent change for AMZN on 2025-01-27 during 11:30 to 12:00: 0.4180%
# Percent change for AMZN on 2025-01-27 during 12:00 to 12:30: -0.2939%
# Percent change for AMZN on 2025-01-27 during 12:30 to 13:00: -0.2541%
# Percent change for AMZN on 2025-01-27 during 13:00 to 13:30: 0.2416%
# Percent change for AMZN on 2025-01-27 during 13:30 to 14:00: 0.4392%
# Percent change for AMZN on 2025-01-27 during 14:00 to 14:30: 0.4761%
# Percent change for AMZN on 2025-01-27 during 14:30 to 15:00: -0.9851%
# Percent change for AMZN on 2025-01-27 during 15:00 to 15:30: 0.2776%
# Missing data for AMZN on 2025-01-27 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for AMZN saved to 'percent_changes/AMZN.csv'.
#
# Previous close for AMZN on 2025-01-27 is 235.44000244140625.
# Open price for AMZN on 2025-01-28 at 09:30 is 234.3650054931641.
# Overnight change for AMZN on 2025-01-28: -0.4566%
# Percent change for AMZN on 2025-01-28 during 09:30 to 10:00: 1.2886%
# Percent change for AMZN on 2025-01-28 during 10:00 to 10:30: 1.4501%
# Percent change for AMZN on 2025-01-28 during 10:30 to 11:00: 0.3561%
# Percent change for AMZN on 2025-01-28 during 11:00 to 11:30: -0.4485%
# Percent change for AMZN on 2025-01-28 during 11:30 to 12:00: 0.1878%
# Percent change for AMZN on 2025-01-28 during 12:00 to 12:30: 0.4311%
# Percent change for AMZN on 2025-01-28 during 12:30 to 13:00: -0.2024%
# Percent change for AMZN on 2025-01-28 during 13:00 to 13:30: -0.5196%
# Percent change for AMZN on 2025-01-28 during 13:30 to 14:00: -0.0209%
# Percent change for AMZN on 2025-01-28 during 14:00 to 14:30: 0.1337%
# Percent change for AMZN on 2025-01-28 during 14:30 to 15:00: -0.0292%
# Percent change for AMZN on 2025-01-28 during 15:00 to 15:30: -0.3422%
# Missing data for AMZN on 2025-01-28 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for AMZN saved to 'percent_changes/AMZN.csv'.
#
# Previous close for AMZN on 2025-01-28 is 238.22000122070312.
# Open price for AMZN on 2025-01-29 at 09:30 is 239.01499938964844.
# Overnight change for AMZN on 2025-01-29: 0.3337%
# Percent change for AMZN on 2025-01-29 during 09:30 to 10:00: -0.7866%
# Percent change for AMZN on 2025-01-29 during 10:00 to 10:30: 0.5946%
# Percent change for AMZN on 2025-01-29 during 10:30 to 11:00: 0.1474%
# Percent change for AMZN on 2025-01-29 during 11:00 to 11:30: -0.2811%
# Percent change for AMZN on 2025-01-29 during 11:30 to 12:00: -0.0357%
# Percent change for AMZN on 2025-01-29 during 12:00 to 12:30: 0.4168%
# Percent change for AMZN on 2025-01-29 during 12:30 to 13:00: -0.3482%
# Percent change for AMZN on 2025-01-29 during 13:00 to 13:30: 0.0253%
# Percent change for AMZN on 2025-01-29 during 13:30 to 14:00: -0.2063%
# Percent change for AMZN on 2025-01-29 during 14:00 to 14:30: -0.2947%
# Percent change for AMZN on 2025-01-29 during 14:30 to 15:00: 0.4436%
# Percent change for AMZN on 2025-01-29 during 15:00 to 15:30: 0.0925%
# Missing data for AMZN on 2025-01-29 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for AMZN saved to 'percent_changes/AMZN.csv'.
#
# Previous close for AMZN on 2025-01-29 is 237.0500030517578.
# Open price for AMZN on 2025-01-30 at 09:30 is 237.3099975585937.
# Overnight change for AMZN on 2025-01-30: 0.1097%
# Percent change for AMZN on 2025-01-30 during 09:30 to 10:00: -0.3582%
# Percent change for AMZN on 2025-01-30 during 10:00 to 10:30: -0.7658%
# Percent change for AMZN on 2025-01-30 during 10:30 to 11:00: -0.7729%
# Percent change for AMZN on 2025-01-30 during 11:00 to 11:30: 0.3023%
# Percent change for AMZN on 2025-01-30 during 11:30 to 12:00: 0.3376%
# Percent change for AMZN on 2025-01-30 during 12:00 to 12:30: -0.3484%
# Percent change for AMZN on 2025-01-30 during 12:30 to 13:00: 0.0254%
# Percent change for AMZN on 2025-01-30 during 13:00 to 13:30: 0.1472%
# Percent change for AMZN on 2025-01-30 during 13:30 to 14:00: 0.3365%
# Percent change for AMZN on 2025-01-30 during 14:00 to 14:30: -0.2864%
# Percent change for AMZN on 2025-01-30 during 14:30 to 15:00: 0.3872%
# Percent change for AMZN on 2025-01-30 during 15:00 to 15:30: -0.0721%
# Missing data for AMZN on 2025-01-30 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for AMZN saved to 'percent_changes/AMZN.csv'.
#
# Processing ticker: JPM
# Successfully read CSV for JPM.
# Converted timezone for JPM to Eastern Time.
# Previous close for JPM on 2025-01-22 is 262.8699951171875.
# Open price for JPM on 2025-01-23 at 09:30 is 264.69000244140625.
# Overnight change for JPM on 2025-01-23: 0.6924%
# Percent change for JPM on 2025-01-23 during 09:30 to 10:00: 0.5818%
# Percent change for JPM on 2025-01-23 during 10:00 to 10:30: -0.5370%
# Percent change for JPM on 2025-01-23 during 10:30 to 11:00: 0.0226%
# Percent change for JPM on 2025-01-23 during 11:00 to 11:30: -0.1957%
# Percent change for JPM on 2025-01-23 during 11:30 to 12:00: -0.0271%
# Percent change for JPM on 2025-01-23 during 12:00 to 12:30: 0.0624%
# Percent change for JPM on 2025-01-23 during 12:30 to 13:00: 0.3231%
# Percent change for JPM on 2025-01-23 during 13:00 to 13:30: -0.0396%
# Percent change for JPM on 2025-01-23 during 13:30 to 14:00: -0.1527%
# Percent change for JPM on 2025-01-23 during 14:00 to 14:30: 0.1491%
# Percent change for JPM on 2025-01-23 during 14:30 to 15:00: 0.0396%
# Percent change for JPM on 2025-01-23 during 15:00 to 15:30: 0.0302%
# Missing data for JPM on 2025-01-23 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for JPM saved to 'percent_changes/JPM.csv'.
#
# Previous close for JPM on 2025-01-23 is 265.94000244140625.
# Open price for JPM on 2025-01-24 at 09:30 is 263.69000244140625.
# Overnight change for JPM on 2025-01-24: -0.8461%
# Percent change for JPM on 2025-01-24 during 09:30 to 10:00: 0.8798%
# Percent change for JPM on 2025-01-24 during 10:00 to 10:30: -0.3759%
# Percent change for JPM on 2025-01-24 during 10:30 to 11:00: -0.2224%
# Percent change for JPM on 2025-01-24 during 11:00 to 11:30: 0.0715%
# Percent change for JPM on 2025-01-24 during 11:30 to 12:00: -0.0397%
# Percent change for JPM on 2025-01-24 during 12:00 to 12:30: 0.0151%
# Percent change for JPM on 2025-01-24 during 12:30 to 13:00: 0.0340%
# Percent change for JPM on 2025-01-24 during 13:00 to 13:30: -0.0679%
# Percent change for JPM on 2025-01-24 during 13:30 to 14:00: -0.0151%
# Percent change for JPM on 2025-01-24 during 14:00 to 14:30: -0.1501%
# Percent change for JPM on 2025-01-24 during 14:30 to 15:00: -0.1702%
# Percent change for JPM on 2025-01-24 during 15:00 to 15:30: 0.1649%
# Missing data for JPM on 2025-01-24 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for JPM saved to 'percent_changes/JPM.csv'.
#
# Previous close for JPM on 2025-01-24 is 264.8099975585937.
# Open price for JPM on 2025-01-27 at 09:30 is 264.4349975585937.
# Overnight change for JPM on 2025-01-27: -0.1416%
# Percent change for JPM on 2025-01-27 during 09:30 to 10:00: 0.1683%
# Percent change for JPM on 2025-01-27 during 10:00 to 10:30: -0.4345%
# Percent change for JPM on 2025-01-27 during 10:30 to 11:00: 0.1498%
# Percent change for JPM on 2025-01-27 during 11:00 to 11:30: -0.1250%
# Percent change for JPM on 2025-01-27 during 11:30 to 12:00: 0.1936%
# Percent change for JPM on 2025-01-27 during 12:00 to 12:30: 0.1250%
# Percent change for JPM on 2025-01-27 during 12:30 to 13:00: -0.2138%
# Percent change for JPM on 2025-01-27 during 13:00 to 13:30: 0.1202%
# Percent change for JPM on 2025-01-27 during 13:30 to 14:00: 0.1629%
# Percent change for JPM on 2025-01-27 during 14:00 to 14:30: 0.2042%
# Percent change for JPM on 2025-01-27 during 14:30 to 15:00: -0.1676%
# Percent change for JPM on 2025-01-27 during 15:00 to 15:30: 0.1571%
# Missing data for JPM on 2025-01-27 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for JPM saved to 'percent_changes/JPM.csv'.
#
# Previous close for JPM on 2025-01-27 is 265.9100036621094.
# Open price for JPM on 2025-01-28 at 09:30 is 265.8500061035156.
# Overnight change for JPM on 2025-01-28: -0.0226%
# Percent change for JPM on 2025-01-28 during 09:30 to 10:00: -0.1317%
# Percent change for JPM on 2025-01-28 during 10:00 to 10:30: -0.0621%
# Percent change for JPM on 2025-01-28 during 10:30 to 11:00: 0.2468%
# Percent change for JPM on 2025-01-28 during 11:00 to 11:30: -0.2030%
# Percent change for JPM on 2025-01-28 during 11:30 to 12:00: -0.1243%
# Percent change for JPM on 2025-01-28 during 12:00 to 12:30: 0.3434%
# Percent change for JPM on 2025-01-28 during 12:30 to 13:00: 0.0188%
# Percent change for JPM on 2025-01-28 during 13:00 to 13:30: 0.0956%
# Percent change for JPM on 2025-01-28 during 13:30 to 14:00: 0.0038%
# Percent change for JPM on 2025-01-28 during 14:00 to 14:30: 0.0825%
# Percent change for JPM on 2025-01-28 during 14:30 to 15:00: 0.0939%
# Percent change for JPM on 2025-01-28 during 15:00 to 15:30: 0.0122%
# Missing data for JPM on 2025-01-28 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for JPM saved to 'percent_changes/JPM.csv'.
#
# Previous close for JPM on 2025-01-28 is 267.1199951171875.
# Open price for JPM on 2025-01-29 at 09:30 is 267.2099914550781.
# Overnight change for JPM on 2025-01-29: 0.0337%
# Percent change for JPM on 2025-01-29 during 09:30 to 10:00: 1.1115%
# Percent change for JPM on 2025-01-29 during 10:00 to 10:30: 0.0000%
# Percent change for JPM on 2025-01-29 during 10:30 to 11:00: -0.2889%
# Percent change for JPM on 2025-01-29 during 11:00 to 11:30: 0.0594%
# Percent change for JPM on 2025-01-29 during 11:30 to 12:00: -0.3453%
# Percent change for JPM on 2025-01-29 during 12:00 to 12:30: -0.3666%
# Percent change for JPM on 2025-01-29 during 12:30 to 13:00: -0.1345%
# Percent change for JPM on 2025-01-29 during 13:00 to 13:30: -0.2469%
# Percent change for JPM on 2025-01-29 during 13:30 to 14:00: -0.3674%
# Percent change for JPM on 2025-01-29 during 14:00 to 14:30: -0.0563%
# Percent change for JPM on 2025-01-29 during 14:30 to 15:00: 0.4473%
# Percent change for JPM on 2025-01-29 during 15:00 to 15:30: -0.0273%
# Missing data for JPM on 2025-01-29 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for JPM saved to 'percent_changes/JPM.csv'.
#
# Previous close for JPM on 2025-01-29 is 266.5899963378906.
# Open price for JPM on 2025-01-30 at 09:30 is 268.6300048828125.
# Overnight change for JPM on 2025-01-30: 0.7652%
# Percent change for JPM on 2025-01-30 during 09:30 to 10:00: -0.3239%
# Percent change for JPM on 2025-01-30 during 10:00 to 10:30: -0.1758%
# Percent change for JPM on 2025-01-30 during 10:30 to 11:00: 0.2366%
# Percent change for JPM on 2025-01-30 during 11:00 to 11:30: 0.1889%
# Percent change for JPM on 2025-01-30 during 11:30 to 12:00: 0.3267%
# Percent change for JPM on 2025-01-30 during 12:00 to 12:30: -0.2101%
# Percent change for JPM on 2025-01-30 during 12:30 to 13:00: 0.1584%
# Percent change for JPM on 2025-01-30 during 13:00 to 13:30: 0.2272%
# Percent change for JPM on 2025-01-30 during 13:30 to 14:00: 0.1356%
# Percent change for JPM on 2025-01-30 during 14:00 to 14:30: -0.3117%
# Percent change for JPM on 2025-01-30 during 14:30 to 15:00: 0.0689%
# Percent change for JPM on 2025-01-30 during 15:00 to 15:30: -0.0186%
# Missing data for JPM on 2025-01-30 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for JPM saved to 'percent_changes/JPM.csv'.
#
# Processing ticker: JNJ
# Successfully read CSV for JNJ.
# Converted timezone for JNJ to Eastern Time.
# Previous close for JNJ on 2025-01-22 is 145.25999450683594.
# Open price for JNJ on 2025-01-23 at 09:30 is 145.44000244140625.
# Overnight change for JNJ on 2025-01-23: 0.1239%
# Percent change for JNJ on 2025-01-23 during 09:30 to 10:00: 0.7426%
# Percent change for JNJ on 2025-01-23 during 10:00 to 10:30: -0.1268%
# Percent change for JNJ on 2025-01-23 during 10:30 to 11:00: 0.6480%
# Percent change for JNJ on 2025-01-23 during 11:00 to 11:30: 0.2612%
# Percent change for JNJ on 2025-01-23 during 11:30 to 12:00: -0.7438%
# Percent change for JNJ on 2025-01-23 during 12:00 to 12:30: -0.1464%
# Percent change for JNJ on 2025-01-23 during 12:30 to 13:00: 0.1023%
# Percent change for JNJ on 2025-01-23 during 13:00 to 13:30: 0.0273%
# Percent change for JNJ on 2025-01-23 during 13:30 to 14:00: 0.1124%
# Percent change for JNJ on 2025-01-23 during 14:00 to 14:30: -0.3273%
# Percent change for JNJ on 2025-01-23 during 14:30 to 15:00: 0.0648%
# Percent change for JNJ on 2025-01-23 during 15:00 to 15:30: 0.0409%
# Missing data for JNJ on 2025-01-23 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for JNJ saved to 'percent_changes/JNJ.csv'.
#
# Previous close for JNJ on 2025-01-23 is 146.61000061035156.
# Open price for JNJ on 2025-01-24 at 09:30 is 146.80499267578125.
# Overnight change for JNJ on 2025-01-24: 0.1330%
# Percent change for JNJ on 2025-01-24 during 09:30 to 10:00: 0.0545%
# Percent change for JNJ on 2025-01-24 during 10:00 to 10:30: -0.1057%
# Percent change for JNJ on 2025-01-24 during 10:30 to 11:00: 0.0955%
# Percent change for JNJ on 2025-01-24 during 11:00 to 11:30: 0.3205%
# Percent change for JNJ on 2025-01-24 during 11:30 to 12:00: -0.2225%
# Percent change for JNJ on 2025-01-24 during 12:00 to 12:30: -0.2042%
# Percent change for JNJ on 2025-01-24 during 12:30 to 13:00: 0.0341%
# Percent change for JNJ on 2025-01-24 during 13:00 to 13:30: -0.1635%
# Percent change for JNJ on 2025-01-24 during 13:30 to 14:00: 0.2455%
# Percent change for JNJ on 2025-01-24 during 14:00 to 14:30: -0.0034%
# Percent change for JNJ on 2025-01-24 during 14:30 to 15:00: 0.0647%
# Percent change for JNJ on 2025-01-24 during 15:00 to 15:30: -0.0680%
# Missing data for JNJ on 2025-01-24 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for JNJ saved to 'percent_changes/JNJ.csv'.
#
# Previous close for JNJ on 2025-01-24 is 146.81500244140625.
# Open price for JNJ on 2025-01-27 at 09:30 is 148.4499969482422.
# Overnight change for JNJ on 2025-01-27: 1.1136%
# Percent change for JNJ on 2025-01-27 during 09:30 to 10:00: 1.1017%
# Percent change for JNJ on 2025-01-27 during 10:00 to 10:30: 0.4600%
# Percent change for JNJ on 2025-01-27 during 10:30 to 11:00: -0.0696%
# Percent change for JNJ on 2025-01-27 during 11:00 to 11:30: 0.3983%
# Percent change for JNJ on 2025-01-27 during 11:30 to 12:00: -0.1255%
# Percent change for JNJ on 2025-01-27 during 12:00 to 12:30: 0.1386%
# Percent change for JNJ on 2025-01-27 during 12:30 to 13:00: 0.2175%
# Percent change for JNJ on 2025-01-27 during 13:00 to 13:30: -0.0460%
# Percent change for JNJ on 2025-01-27 during 13:30 to 14:00: 0.7201%
# Percent change for JNJ on 2025-01-27 during 14:00 to 14:30: -0.1045%
# Percent change for JNJ on 2025-01-27 during 14:30 to 15:00: 0.2061%
# Percent change for JNJ on 2025-01-27 during 15:00 to 15:30: 0.1046%
# Missing data for JNJ on 2025-01-27 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for JNJ saved to 'percent_changes/JNJ.csv'.
#
# Previous close for JNJ on 2025-01-27 is 152.88999938964844.
# Open price for JNJ on 2025-01-28 at 09:30 is 152.66000366210938.
# Overnight change for JNJ on 2025-01-28: -0.1504%
# Percent change for JNJ on 2025-01-28 during 09:30 to 10:00: -0.9499%
# Percent change for JNJ on 2025-01-28 during 10:00 to 10:30: -0.0528%
# Percent change for JNJ on 2025-01-28 during 10:30 to 11:00: 0.3136%
# Percent change for JNJ on 2025-01-28 during 11:00 to 11:30: -0.2896%
# Percent change for JNJ on 2025-01-28 during 11:30 to 12:00: -0.0551%
# Percent change for JNJ on 2025-01-28 during 12:00 to 12:30: -0.0380%
# Percent change for JNJ on 2025-01-28 during 12:30 to 13:00: 0.0066%
# Percent change for JNJ on 2025-01-28 during 13:00 to 13:30: -0.1663%
# Percent change for JNJ on 2025-01-28 during 13:30 to 14:00: -0.0298%
# Percent change for JNJ on 2025-01-28 during 14:00 to 14:30: -0.0530%
# Percent change for JNJ on 2025-01-28 during 14:30 to 15:00: -0.2119%
# Percent change for JNJ on 2025-01-28 during 15:00 to 15:30: -0.0930%
# Missing data for JNJ on 2025-01-28 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for JNJ saved to 'percent_changes/JNJ.csv'.
#
# Previous close for JNJ on 2025-01-28 is 150.38999938964844.
# Open price for JNJ on 2025-01-29 at 09:30 is 150.5.
# Overnight change for JNJ on 2025-01-29: 0.0731%
# Percent change for JNJ on 2025-01-29 during 09:30 to 10:00: 0.1462%
# Percent change for JNJ on 2025-01-29 during 10:00 to 10:30: 0.4379%
# Percent change for JNJ on 2025-01-29 during 10:30 to 11:00: -0.0594%
# Percent change for JNJ on 2025-01-29 during 11:00 to 11:30: -0.0066%
# Percent change for JNJ on 2025-01-29 during 11:30 to 12:00: 0.0396%
# Percent change for JNJ on 2025-01-29 during 12:00 to 12:30: 0.0627%
# Percent change for JNJ on 2025-01-29 during 12:30 to 13:00: -0.2374%
# Percent change for JNJ on 2025-01-29 during 13:00 to 13:30: 0.0146%
# Percent change for JNJ on 2025-01-29 during 13:30 to 14:00: -0.1057%
# Percent change for JNJ on 2025-01-29 during 14:00 to 14:30: -0.0643%
# Percent change for JNJ on 2025-01-29 during 14:30 to 15:00: 0.2084%
# Percent change for JNJ on 2025-01-29 during 15:00 to 15:30: 0.0726%
# Missing data for JNJ on 2025-01-29 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for JNJ saved to 'percent_changes/JNJ.csv'.
#
# Previous close for JNJ on 2025-01-29 is 151.13999938964844.
# Open price for JNJ on 2025-01-30 at 09:30 is 151.91000366210938.
# Overnight change for JNJ on 2025-01-30: 0.5095%
# Percent change for JNJ on 2025-01-30 during 09:30 to 10:00: 0.1514%
# Percent change for JNJ on 2025-01-30 during 10:00 to 10:30: 0.0888%
# Percent change for JNJ on 2025-01-30 during 10:30 to 11:00: 0.3682%
# Percent change for JNJ on 2025-01-30 during 11:00 to 11:30: -0.3023%
# Percent change for JNJ on 2025-01-30 during 11:30 to 12:00: 0.0820%
# Percent change for JNJ on 2025-01-30 during 12:00 to 12:30: 0.1803%
# Percent change for JNJ on 2025-01-30 during 12:30 to 13:00: 0.4486%
# Percent change for JNJ on 2025-01-30 during 13:00 to 13:30: 0.1566%
# Percent change for JNJ on 2025-01-30 during 13:30 to 14:00: 0.3616%
# Percent change for JNJ on 2025-01-30 during 14:00 to 14:30: -0.0134%
# Percent change for JNJ on 2025-01-30 during 14:30 to 15:00: -0.2273%
# Percent change for JNJ on 2025-01-30 during 15:00 to 15:30: -0.0455%
# Missing data for JNJ on 2025-01-30 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for JNJ saved to 'percent_changes/JNJ.csv'.
#
# Processing ticker: NVDA
# Successfully read CSV for NVDA.
# Converted timezone for NVDA to Eastern Time.
# Previous close for NVDA on 2025-01-22 is 147.0399932861328.
# Open price for NVDA on 2025-01-23 at 09:30 is 145.02000427246094.
# Overnight change for NVDA on 2025-01-23: -1.3738%
# Percent change for NVDA on 2025-01-23 during 09:30 to 10:00: 0.3518%
# Percent change for NVDA on 2025-01-23 during 10:00 to 10:30: -0.0894%
# Percent change for NVDA on 2025-01-23 during 10:30 to 11:00: 0.4815%
# Percent change for NVDA on 2025-01-23 during 11:00 to 11:30: -0.1195%
# Percent change for NVDA on 2025-01-23 during 11:30 to 12:00: -0.0103%
# Percent change for NVDA on 2025-01-23 during 12:00 to 12:30: -0.3360%
# Percent change for NVDA on 2025-01-23 during 12:30 to 13:00: 0.0653%
# Percent change for NVDA on 2025-01-23 during 13:00 to 13:30: 0.3393%
# Percent change for NVDA on 2025-01-23 during 13:30 to 14:00: 0.2536%
# Percent change for NVDA on 2025-01-23 during 14:00 to 14:30: 0.2214%
# Percent change for NVDA on 2025-01-23 during 14:30 to 15:00: -0.1530%
# Percent change for NVDA on 2025-01-23 during 15:00 to 15:30: 0.1470%
# Missing data for NVDA on 2025-01-23 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for NVDA saved to 'percent_changes/NVDA.csv'.
#
# Previous close for NVDA on 2025-01-23 is 147.1999969482422.
# Open price for NVDA on 2025-01-24 at 09:30 is 148.5.
# Overnight change for NVDA on 2025-01-24: 0.8832%
# Percent change for NVDA on 2025-01-24 during 09:30 to 10:00: -0.3636%
# Percent change for NVDA on 2025-01-24 during 10:00 to 10:30: -1.0686%
# Percent change for NVDA on 2025-01-24 during 10:30 to 11:00: -0.4348%
# Percent change for NVDA on 2025-01-24 during 11:00 to 11:30: -0.0965%
# Percent change for NVDA on 2025-01-24 during 11:30 to 12:00: -0.5372%
# Percent change for NVDA on 2025-01-24 during 12:00 to 12:30: 0.1247%
# Percent change for NVDA on 2025-01-24 during 12:30 to 13:00: -0.7651%
# Percent change for NVDA on 2025-01-24 during 13:00 to 13:30: 0.1467%
# Percent change for NVDA on 2025-01-24 during 13:30 to 14:00: -0.6416%
# Percent change for NVDA on 2025-01-24 during 14:00 to 14:30: 0.1124%
# Percent change for NVDA on 2025-01-24 during 14:30 to 15:00: -0.0527%
# Percent change for NVDA on 2025-01-24 during 15:00 to 15:30: -0.1335%
# Missing data for NVDA on 2025-01-24 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for NVDA saved to 'percent_changes/NVDA.csv'.
#
# Previous close for NVDA on 2025-01-24 is 142.60040283203125.
# Open price for NVDA on 2025-01-27 at 09:30 is 124.79000091552734.
# Overnight change for NVDA on 2025-01-27: -12.4897%
# Percent change for NVDA on 2025-01-27 during 09:30 to 10:00: 1.5137%
# Percent change for NVDA on 2025-01-27 during 10:00 to 10:30: -1.9783%
# Percent change for NVDA on 2025-01-27 during 10:30 to 11:00: -0.9394%
# Percent change for NVDA on 2025-01-27 during 11:00 to 11:30: -3.1385%
# Percent change for NVDA on 2025-01-27 during 11:30 to 12:00: 1.3513%
# Percent change for NVDA on 2025-01-27 during 12:00 to 12:30: -0.5405%
# Percent change for NVDA on 2025-01-27 during 12:30 to 13:00: -0.9769%
# Percent change for NVDA on 2025-01-27 during 13:00 to 13:30: -0.3165%
# Percent change for NVDA on 2025-01-27 during 13:30 to 14:00: -0.0220%
# Percent change for NVDA on 2025-01-27 during 14:00 to 14:30: 0.6619%
# Percent change for NVDA on 2025-01-27 during 14:30 to 15:00: -0.8417%
# Percent change for NVDA on 2025-01-27 during 15:00 to 15:30: 0.1399%
# Missing data for NVDA on 2025-01-27 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for NVDA saved to 'percent_changes/NVDA.csv'.
#
# Previous close for NVDA on 2025-01-27 is 118.51000213623048.
# Open price for NVDA on 2025-01-28 at 09:30 is 121.80500030517578.
# Overnight change for NVDA on 2025-01-28: 2.7804%
# Percent change for NVDA on 2025-01-28 during 09:30 to 10:00: -1.4737%
# Percent change for NVDA on 2025-01-28 during 10:00 to 10:30: 1.5326%
# Percent change for NVDA on 2025-01-28 during 10:30 to 11:00: -0.7400%
# Percent change for NVDA on 2025-01-28 during 11:00 to 11:30: 0.0870%
# Percent change for NVDA on 2025-01-28 during 11:30 to 12:00: 2.2563%
# Percent change for NVDA on 2025-01-28 during 12:00 to 12:30: 1.8439%
# Percent change for NVDA on 2025-01-28 during 12:30 to 13:00: -0.2023%
# Percent change for NVDA on 2025-01-28 during 13:00 to 13:30: 0.4014%
# Percent change for NVDA on 2025-01-28 during 13:30 to 14:00: 0.3548%
# Percent change for NVDA on 2025-01-28 during 14:00 to 14:30: 0.2564%
# Percent change for NVDA on 2025-01-28 during 14:30 to 15:00: 0.1467%
# Percent change for NVDA on 2025-01-28 during 15:00 to 15:30: -0.0612%
# Missing data for NVDA on 2025-01-28 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for NVDA saved to 'percent_changes/NVDA.csv'.
#
# Previous close for NVDA on 2025-01-28 is 128.9801025390625.
# Open price for NVDA on 2025-01-29 at 09:30 is 126.46150207519533.
# Overnight change for NVDA on 2025-01-29: -1.9527%
# Percent change for NVDA on 2025-01-29 during 09:30 to 10:00: -0.8869%
# Percent change for NVDA on 2025-01-29 during 10:00 to 10:30: -0.8621%
# Percent change for NVDA on 2025-01-29 during 10:30 to 11:00: -0.9723%
# Percent change for NVDA on 2025-01-29 during 11:00 to 11:30: 0.1548%
# ...
# Percent change for ABBV on 2025-01-29 during 13:00 to 13:30: 0.0938%
# Percent change for ABBV on 2025-01-29 during 13:30 to 14:00: -0.5001%
# Percent change for ABBV on 2025-01-29 during 14:00 to 14:30: -0.1256%
# Percent change for ABBV on 2025-01-29 during 14:30 to 15:00: 0.2689%
# Percent change for ABBV on 2025-01-29 during 15:00 to 15:30: 0.0623%
# Missing data for ABBV on 2025-01-29 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for ABBV saved to 'percent_changes/ABBV.csv'.
#
# Previous close for ABBV on 2025-01-29 is 175.24000549316406.
# Open price for ABBV on 2025-01-30 at 09:30 is 176.00999450683594.
# Overnight change for ABBV on 2025-01-30: 0.4394%
# Percent change for ABBV on 2025-01-30 during 09:30 to 10:00: -0.3068%
# Percent change for ABBV on 2025-01-30 during 10:00 to 10:30: -0.1198%
# Percent change for ABBV on 2025-01-30 during 10:30 to 11:00: 0.0057%
# Percent change for ABBV on 2025-01-30 during 11:00 to 11:30: 0.3055%
# Percent change for ABBV on 2025-01-30 during 11:30 to 12:00: -0.3729%
# Percent change for ABBV on 2025-01-30 during 12:00 to 12:30: -0.0057%
# Percent change for ABBV on 2025-01-30 during 12:30 to 13:00: 0.3260%
# Percent change for ABBV on 2025-01-30 during 13:00 to 13:30: 0.1881%
# Percent change for ABBV on 2025-01-30 during 13:30 to 14:00: -0.0001%
# Percent change for ABBV on 2025-01-30 during 14:00 to 14:30: 0.1052%
# Percent change for ABBV on 2025-01-30 during 14:30 to 15:00: -0.2386%
# Percent change for ABBV on 2025-01-30 during 15:00 to 15:30: -0.2391%
# Missing data for ABBV on 2025-01-30 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for ABBV saved to 'percent_changes/ABBV.csv'.
#
# Processing ticker: UNH
# Successfully read CSV for UNH.
# Converted timezone for UNH to Eastern Time.
# Previous close for UNH on 2025-01-22 is 519.3200073242188.
# Open price for UNH on 2025-01-23 at 09:30 is 527.8699951171875.
# Overnight change for UNH on 2025-01-23: 1.6464%
# Percent change for UNH on 2025-01-23 during 09:30 to 10:00: -1.4577%
# Percent change for UNH on 2025-01-23 during 10:00 to 10:30: 0.2402%
# Percent change for UNH on 2025-01-23 during 10:30 to 11:00: 0.5038%
# Percent change for UNH on 2025-01-23 during 11:00 to 11:30: 0.5809%
# Percent change for UNH on 2025-01-23 during 11:30 to 12:00: -0.2038%
# Percent change for UNH on 2025-01-23 during 12:00 to 12:30: -0.0132%
# Percent change for UNH on 2025-01-23 during 12:30 to 13:00: 0.2214%
# Percent change for UNH on 2025-01-23 during 13:00 to 13:30: 0.1568%
# Percent change for UNH on 2025-01-23 during 13:30 to 14:00: -0.0968%
# Percent change for UNH on 2025-01-23 during 14:00 to 14:30: -0.0567%
# Percent change for UNH on 2025-01-23 during 14:30 to 15:00: -0.2781%
# Percent change for UNH on 2025-01-23 during 15:00 to 15:30: 0.0739%
# Missing data for UNH on 2025-01-23 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for UNH saved to 'percent_changes/UNH.csv'.
#
# Previous close for UNH on 2025-01-23 is 529.6400146484375.
# Open price for UNH on 2025-01-24 at 09:30 is 528.1099853515625.
# Overnight change for UNH on 2025-01-24: -0.2889%
# Percent change for UNH on 2025-01-24 during 09:30 to 10:00: -0.1401%
# Percent change for UNH on 2025-01-24 during 10:00 to 10:30: 0.4724%
# Percent change for UNH on 2025-01-24 during 10:30 to 11:00: -0.1217%
# Percent change for UNH on 2025-01-24 during 11:00 to 11:30: 0.2153%
# Percent change for UNH on 2025-01-24 during 11:30 to 12:00: -0.1658%
# Percent change for UNH on 2025-01-24 during 12:00 to 12:30: 0.2291%
# Percent change for UNH on 2025-01-24 during 12:30 to 13:00: 0.2652%
# Percent change for UNH on 2025-01-24 during 13:00 to 13:30: 0.0638%
# Percent change for UNH on 2025-01-24 during 13:30 to 14:00: -0.0141%
# Percent change for UNH on 2025-01-24 during 14:00 to 14:30: -0.1256%
# Percent change for UNH on 2025-01-24 during 14:30 to 15:00: 0.1708%
# Percent change for UNH on 2025-01-24 during 15:00 to 15:30: -0.2108%
# Missing data for UNH on 2025-01-24 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for UNH saved to 'percent_changes/UNH.csv'.
#
# Previous close for UNH on 2025-01-24 is 532.5.
# Open price for UNH on 2025-01-27 at 09:30 is 539.97998046875.
# Overnight change for UNH on 2025-01-27: 1.4047%
# Percent change for UNH on 2025-01-27 during 09:30 to 10:00: 0.6982%
# Percent change for UNH on 2025-01-27 during 10:00 to 10:30: 0.5061%
# Percent change for UNH on 2025-01-27 during 10:30 to 11:00: -0.2016%
# Percent change for UNH on 2025-01-27 during 11:00 to 11:30: 0.0920%
# Percent change for UNH on 2025-01-27 during 11:30 to 12:00: 0.2556%
# Percent change for UNH on 2025-01-27 during 12:00 to 12:30: 0.0440%
# Percent change for UNH on 2025-01-27 during 12:30 to 13:00: 0.0868%
# Percent change for UNH on 2025-01-27 during 13:00 to 13:30: -0.2500%
# Percent change for UNH on 2025-01-27 during 13:30 to 14:00: 0.0844%
# Percent change for UNH on 2025-01-27 during 14:00 to 14:30: -0.4658%
# Percent change for UNH on 2025-01-27 during 14:30 to 15:00: 0.1049%
# Percent change for UNH on 2025-01-27 during 15:00 to 15:30: -0.1582%
# Missing data for UNH on 2025-01-27 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for UNH saved to 'percent_changes/UNH.csv'.
#
# Previous close for UNH on 2025-01-27 is 543.719970703125.
# Open price for UNH on 2025-01-28 at 09:30 is 543.010009765625.
# Overnight change for UNH on 2025-01-28: -0.1306%
# Percent change for UNH on 2025-01-28 during 09:30 to 10:00: -0.5473%
# Percent change for UNH on 2025-01-28 during 10:00 to 10:30: 0.1405%
# Percent change for UNH on 2025-01-28 during 10:30 to 11:00: 0.1016%
# Percent change for UNH on 2025-01-28 during 11:00 to 11:30: -0.4025%
# Percent change for UNH on 2025-01-28 during 11:30 to 12:00: 0.1269%
# Percent change for UNH on 2025-01-28 during 12:00 to 12:30: 0.0971%
# Percent change for UNH on 2025-01-28 during 12:30 to 13:00: 0.4520%
# Percent change for UNH on 2025-01-28 during 13:00 to 13:30: 0.0709%
# Percent change for UNH on 2025-01-28 during 13:30 to 14:00: -0.4113%
# Percent change for UNH on 2025-01-28 during 14:00 to 14:30: 0.0850%
# Percent change for UNH on 2025-01-28 during 14:30 to 15:00: 0.0000%
# Percent change for UNH on 2025-01-28 during 15:00 to 15:30: -0.0351%
# Missing data for UNH on 2025-01-28 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for UNH saved to 'percent_changes/UNH.csv'.
#
# Previous close for UNH on 2025-01-28 is 542.3300170898438.
# Open price for UNH on 2025-01-29 at 09:30 is 541.72998046875.
# Overnight change for UNH on 2025-01-29: -0.1106%
# Percent change for UNH on 2025-01-29 during 09:30 to 10:00: -0.3563%
# Percent change for UNH on 2025-01-29 during 10:00 to 10:30: 0.2818%
# Percent change for UNH on 2025-01-29 during 10:30 to 11:00: -0.4381%
# Percent change for UNH on 2025-01-29 during 11:00 to 11:30: 0.1095%
# Percent change for UNH on 2025-01-29 during 11:30 to 12:00: -0.2225%
# Percent change for UNH on 2025-01-29 during 12:00 to 12:30: -0.0130%
# Percent change for UNH on 2025-01-29 during 12:30 to 13:00: -0.1172%
# Percent change for UNH on 2025-01-29 during 13:00 to 13:30: 0.0894%
# Percent change for UNH on 2025-01-29 during 13:30 to 14:00: 0.1730%
# Percent change for UNH on 2025-01-29 during 14:00 to 14:30: -0.7954%
# Percent change for UNH on 2025-01-29 during 14:30 to 15:00: 0.7131%
# Percent change for UNH on 2025-01-29 during 15:00 to 15:30: 0.0539%
# Missing data for UNH on 2025-01-29 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for UNH saved to 'percent_changes/UNH.csv'.
#
# Previous close for UNH on 2025-01-29 is 537.969970703125.
# Open price for UNH on 2025-01-30 at 09:30 is 539.469970703125.
# Overnight change for UNH on 2025-01-30: 0.2788%
# Percent change for UNH on 2025-01-30 during 09:30 to 10:00: 0.2373%
# Percent change for UNH on 2025-01-30 during 10:00 to 10:30: -0.1332%
# Percent change for UNH on 2025-01-30 during 10:30 to 11:00: 0.1696%
# Percent change for UNH on 2025-01-30 during 11:00 to 11:30: -0.1988%
# Percent change for UNH on 2025-01-30 during 11:30 to 12:00: -0.0306%
# Percent change for UNH on 2025-01-30 during 12:00 to 12:30: 0.2455%
# Percent change for UNH on 2025-01-30 during 12:30 to 13:00: 0.0860%
# Percent change for UNH on 2025-01-30 during 13:00 to 13:30: 0.5609%
# Percent change for UNH on 2025-01-30 during 13:30 to 14:00: 0.0515%
# Percent change for UNH on 2025-01-30 during 14:00 to 14:30: -0.0430%
# Percent change for UNH on 2025-01-30 during 14:30 to 15:00: 0.3435%
# Percent change for UNH on 2025-01-30 during 15:00 to 15:30: 0.0339%
# Missing data for UNH on 2025-01-30 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for UNH saved to 'percent_changes/UNH.csv'.
#
# Processing ticker: COST
# Successfully read CSV for COST.
# Converted timezone for COST to Eastern Time.
# Previous close for COST on 2025-01-22 is 944.6799926757812.
# Open price for COST on 2025-01-23 at 09:30 is 941.6900024414062.
# Overnight change for COST on 2025-01-23: -0.3165%
# Percent change for COST on 2025-01-23 during 09:30 to 10:00: -0.1832%
# Percent change for COST on 2025-01-23 during 10:00 to 10:30: -0.3107%
# Percent change for COST on 2025-01-23 during 10:30 to 11:00: 0.0725%
# Missing data for COST on 2025-01-23 during interval 11:00 to 11:30. Skipping this interval.
#
# Missing data for COST on 2025-01-23 during interval 11:30 to 12:00. Skipping this interval.
#
# Percent change for COST on 2025-01-23 during 12:00 to 12:30: -0.1983%
# Percent change for COST on 2025-01-23 during 12:30 to 13:00: 0.0420%
# Percent change for COST on 2025-01-23 during 13:00 to 13:30: 0.2222%
# Missing data for COST on 2025-01-23 during interval 13:30 to 14:00. Skipping this interval.
#
# Missing data for COST on 2025-01-23 during interval 14:00 to 14:30. Skipping this interval.
#
# Percent change for COST on 2025-01-23 during 14:30 to 15:00: 0.0000%
# Percent change for COST on 2025-01-23 during 15:00 to 15:30: -0.0763%
# Missing data for COST on 2025-01-23 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for COST saved to 'percent_changes/COST.csv'.
#
# Previous close for COST on 2025-01-23 is 941.97998046875.
# Open price for COST on 2025-01-24 at 09:30 is 940.2050170898438.
# Overnight change for COST on 2025-01-24: -0.1884%
# Percent change for COST on 2025-01-24 during 09:30 to 10:00: 0.3132%
# Percent change for COST on 2025-01-24 during 10:00 to 10:30: 0.0477%
# Percent change for COST on 2025-01-24 during 10:30 to 11:00: 0.0971%
# Percent change for COST on 2025-01-24 during 11:00 to 11:30: -0.0276%
# Percent change for COST on 2025-01-24 during 11:30 to 12:00: -0.3307%
# Percent change for COST on 2025-01-24 during 12:00 to 12:30: 0.0149%
# Percent change for COST on 2025-01-24 during 12:30 to 13:00: -0.1093%
# Percent change for COST on 2025-01-24 during 13:00 to 13:30: -0.2413%
# Percent change for COST on 2025-01-24 during 13:30 to 14:00: -0.1808%
# Percent change for COST on 2025-01-24 during 14:00 to 14:30: 0.0550%
# Percent change for COST on 2025-01-24 during 14:30 to 15:00: -0.1495%
# Percent change for COST on 2025-01-24 during 15:00 to 15:30: 0.2663%
# Missing data for COST on 2025-01-24 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for COST saved to 'percent_changes/COST.csv'.
#
# Previous close for COST on 2025-01-24 is 939.4199829101562.
# Open price for COST on 2025-01-27 at 09:30 is 930.0.
# Overnight change for COST on 2025-01-27: -1.0027%
# Percent change for COST on 2025-01-27 during 09:30 to 10:00: 0.5955%
# Percent change for COST on 2025-01-27 during 10:00 to 10:30: 0.7647%
# Percent change for COST on 2025-01-27 during 10:30 to 11:00: -0.2877%
# Percent change for COST on 2025-01-27 during 11:00 to 11:30: 0.2702%
# Percent change for COST on 2025-01-27 during 11:30 to 12:00: 0.1146%
# Percent change for COST on 2025-01-27 during 12:00 to 12:30: 0.7760%
# Percent change for COST on 2025-01-27 during 12:30 to 13:00: 0.0353%
# Percent change for COST on 2025-01-27 during 13:00 to 13:30: 0.7344%
# Percent change for COST on 2025-01-27 during 13:30 to 14:00: -0.0324%
# Percent change for COST on 2025-01-27 during 14:00 to 14:30: 0.5576%
# Percent change for COST on 2025-01-27 during 14:30 to 15:00: -0.0062%
# Percent change for COST on 2025-01-27 during 15:00 to 15:30: -0.2108%
# Missing data for COST on 2025-01-27 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for COST saved to 'percent_changes/COST.csv'.
#
# Previous close for COST on 2025-01-27 is 965.0599975585938.
# Open price for COST on 2025-01-28 at 09:30 is 959.25.
# Overnight change for COST on 2025-01-28: -0.6020%
# Percent change for COST on 2025-01-28 during 09:30 to 10:00: 0.2137%
# Percent change for COST on 2025-01-28 during 10:00 to 10:30: -0.3318%
# Percent change for COST on 2025-01-28 during 10:30 to 11:00: -0.0146%
# Percent change for COST on 2025-01-28 during 11:00 to 11:30: -0.1294%
# Percent change for COST on 2025-01-28 during 11:30 to 12:00: 0.2123%
# Percent change for COST on 2025-01-28 during 12:00 to 12:30: 0.2320%
# Percent change for COST on 2025-01-28 during 12:30 to 13:00: 0.2469%
# Percent change for COST on 2025-01-28 during 13:00 to 13:30: 0.0582%
# Percent change for COST on 2025-01-28 during 13:30 to 14:00: -0.1951%
# Percent change for COST on 2025-01-28 during 14:00 to 14:30: 0.1733%
# Percent change for COST on 2025-01-28 during 14:30 to 15:00: -0.2024%
# Percent change for COST on 2025-01-28 during 15:00 to 15:30: 0.3564%
# Missing data for COST on 2025-01-28 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for COST saved to 'percent_changes/COST.csv'.
#
# Previous close for COST on 2025-01-28 is 958.5999755859376.
# Open price for COST on 2025-01-29 at 09:30 is 957.7999877929688.
# Overnight change for COST on 2025-01-29: -0.0835%
# Percent change for COST on 2025-01-29 during 09:30 to 10:00: 0.0423%
# Percent change for COST on 2025-01-29 during 10:00 to 10:30: 0.0261%
# Missing data for COST on 2025-01-29 during interval 10:30 to 11:00. Skipping this interval.
#
# Missing data for COST on 2025-01-29 during interval 11:00 to 11:30. Skipping this interval.
#
# Percent change for COST on 2025-01-29 during 11:30 to 12:00: 0.1228%
# Percent change for COST on 2025-01-29 during 12:00 to 12:30: 0.1660%
# Percent change for COST on 2025-01-29 during 12:30 to 13:00: -0.2232%
# Percent change for COST on 2025-01-29 during 13:00 to 13:30: 0.1561%
# Percent change for COST on 2025-01-29 during 13:30 to 14:00: -0.4207%
# Percent change for COST on 2025-01-29 during 14:00 to 14:30: -0.2624%
# Percent change for COST on 2025-01-29 during 14:30 to 15:00: 0.6285%
# Percent change for COST on 2025-01-29 during 15:00 to 15:30: 0.4527%
# Missing data for COST on 2025-01-29 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for COST saved to 'percent_changes/COST.csv'.
#
# Previous close for COST on 2025-01-29 is 964.0399780273438.
# Open price for COST on 2025-01-30 at 09:30 is 970.2999877929688.
# Overnight change for COST on 2025-01-30: 0.6494%
# Percent change for COST on 2025-01-30 during 09:30 to 10:00: 1.5913%
# Percent change for COST on 2025-01-30 during 10:00 to 10:30: -0.8307%
# Percent change for COST on 2025-01-30 during 10:30 to 11:00: -0.2537%
# Percent change for COST on 2025-01-30 during 11:00 to 11:30: 0.4404%
# Percent change for COST on 2025-01-30 during 11:30 to 12:00: 0.0960%
# Percent change for COST on 2025-01-30 during 12:00 to 12:30: -0.2663%
# Percent change for COST on 2025-01-30 during 12:30 to 13:00: 0.1351%
# Percent change for COST on 2025-01-30 during 13:00 to 13:30: 0.0117%
# Percent change for COST on 2025-01-30 during 13:30 to 14:00: 0.1167%
# Percent change for COST on 2025-01-30 during 14:00 to 14:30: -0.0513%
# Percent change for COST on 2025-01-30 during 14:30 to 15:00: 0.1461%
# Percent change for COST on 2025-01-30 during 15:00 to 15:30: -0.0025%
# Missing data for COST on 2025-01-30 during interval 15:30 to 16:00. Skipping this interval.
#
# Processed percent changes for COST saved to 'percent_changes/COST.csv'.
#
# All tickers processed.

# %%
import pandas as pd
import os
from datetime import datetime
import statsmodels.api as sm


percent_change_dir = "percent_changes"

regression_results_dir = "regression_results"
os.makedirs(regression_results_dir, exist_ok=True)

# List of tickers again
tickers = [
    "GOOG", "MSFT", "BRK-B", "AAPL", "AMZN", "JPM", "JNJ",
    "NVDA", "XOM", "V", "PG", "META", "HD", "SPY", "CVX",
    "MRK", "PEP", "ABBV", "UNH", "COST"
]

exceptions = ["BRK-B"]

processed_tickers = [
    ticker.replace('-', '.') if ticker not in exceptions else ticker
    for ticker in tickers
]

def perform_regression_simple(df):

    X = sm.add_constant(df['r1'])
    y = df['r13']

    model = sm.OLS(y, X).fit()

    results = {
        'Alpha': model.params['const'],
        'Beta_r1': model.params['r1'],
        'p_Alpha': model.pvalues['const'],
        'p_Beta_r1': model.pvalues['r1'],
        'R-squared': model.rsquared
    }

    return results

def perform_regression_multiple(df):

    X = sm.add_constant(df[['r1', 'r2']])
    y = df['r13']

    model = sm.OLS(y, X).fit()

    results = {
        'Alpha': model.params['const'],
        'Beta_r1': model.params['r1'],
        'Beta_r2': model.params['r2'],
        'p_Alpha': model.pvalues['const'],
        'p_Beta_r1': model.pvalues['r1'],
        'p_Beta_r2': model.pvalues['r2'],
        'R-squared': model.rsquared
    }

    return results

def extract_returns(df_pivot, ticker):

    required_intervals = {
        'r1': 'Overnight (16:00 Prev Close to 09:30 Open)',
        'r2': '09:30 to 10:00',
        'r13': '15:00 to 15:30'
    }

    missing = [col for key, col in required_intervals.items() if col not in df_pivot.columns]
    if missing:
        print(f"Ticker {ticker} is missing intervals: {missing}. Skipping.")
        return pd.DataFrame()  # Return empty DataFrame

    df_returns = df_pivot[required_intervals.values()].copy()
    df_returns.columns = ['r1', 'r2', 'r13']

    return df_returns

def generate_summary_table(regression_summary):

    summary_data = []

    for ticker, regressions in regression_summary.items():
        # Simple Regression
        if 'simple' in regressions:
            simple = regressions['simple']
            summary_data.append({
                'Ticker': ticker,
                'Regression Type': 'Simple',
                'Alpha': simple['Alpha'],
                'Beta_r1': simple['Beta_r1'],
                'Beta_r2': '',
                'p_Alpha': simple['p_Alpha'],
                'p_Beta_r1': simple['p_Beta_r1'],
                'p_Beta_r2': '',
                'R-squared': simple['R-squared']
            })
        else:
            summary_data.append({
                'Ticker': ticker,
                'Regression Type': 'Simple',
                'Alpha': 'N/A',
                'Beta_r1': 'N/A',
                'Beta_r2': '',
                'p_Alpha': 'N/A',
                'p_Beta_r1': 'N/A',
                'p_Beta_r2': '',
                'R-squared': 'N/A'
            })

        # Multiple Regression
        if 'multiple' in regressions:
            multiple = regressions['multiple']
            summary_data.append({
                'Ticker': ticker,
                'Regression Type': 'Multiple',
                'Alpha': multiple['Alpha'],
                'Beta_r1': multiple['Beta_r1'],
                'Beta_r2': multiple['Beta_r2'],
                'p_Alpha': multiple['p_Alpha'],
                'p_Beta_r1': multiple['p_Beta_r1'],
                'p_Beta_r2': multiple['p_Beta_r2'],
                'R-squared': multiple['R-squared']
            })
        else:
            summary_data.append({
                'Ticker': ticker,
                'Regression Type': 'Multiple',
                'Alpha': 'N/A',
                'Beta_r1': 'N/A',
                'Beta_r2': 'N/A',
                'p_Alpha': 'N/A',
                'p_Beta_r1': 'N/A',
                'p_Beta_r2': 'N/A',
                'R-squared': 'N/A'
            })

    summary_df = pd.DataFrame(summary_data)
    return summary_df


def main():
    """
    Main function to perform intraday momentum predictive regression analysis.
    """
    regression_summary = {}

    for original_ticker, processed_ticker in zip(tickers, processed_tickers):
        print(f"Processing ticker: {processed_ticker}")

        file_path = os.path.join(percent_change_dir, f"{processed_ticker}.csv")

        if not os.path.exists(file_path):
            print(f"{processed_ticker}.csv does not exist in '{percent_change_dir}'. Skipping.\n")
            continue

        try:
            df = pd.read_csv(file_path)
        except Exception as e:
            print(f"Failed to read {processed_ticker}.csv: {e}\n")
            continue

        try:
            df_pivot = df.pivot(index='Date', columns='Interval', values='Percent Change')
        except Exception as e:
            print(f"Failed to pivot data for {processed_ticker}: {e}\n")
            continue

        # Extract r1, r2, and r13
        df_returns = extract_returns(df_pivot, processed_ticker)

        if df_returns.empty:
            print(f"No valid returns extracted for {processed_ticker}. Skipping regression.\n")
            continue

        df_clean = df_returns.dropna()

        if df_clean.empty:
            print(f"All returns contain NaN for {processed_ticker}. Skipping regression.\n")
            continue

        # Simple Regression
        try:
            simple_results = perform_regression_simple(df_clean)
        except Exception as e:
            print(f"Simple regression failed for {processed_ticker}: {e}\n")
            simple_results = None

        # Multiple Regression
        try:
            multiple_results = perform_regression_multiple(df_clean)
        except Exception as e:
            print(f"Multiple regression failed for {processed_ticker}: {e}\n")
            multiple_results = None

        # Store results
        regression_summary[processed_ticker] = {}
        if simple_results:
            regression_summary[processed_ticker]['simple'] = simple_results
        if multiple_results:
            regression_summary[processed_ticker]['multiple'] = multiple_results

        print(f"Completed regression analysis for {processed_ticker}.\n")

    # Generate summary table
    summary_table = generate_summary_table(regression_summary)

    # Save summary table to CSV
    summary_csv_path = os.path.join(regression_results_dir, "regression_summary_table.csv")
    try:
        summary_table.to_csv(summary_csv_path, index=False)
        print(f"Regression summary table saved to '{summary_csv_path}'.\n")
    except Exception as e:
        print(f"Error saving regression summary table: {e}\n")

    # Display the summary table
    print("Regression Summary Table:")
    print(summary_table)

if __name__ == "__main__":
    main()
# Out:
# Processing ticker: GOOG
# Completed regression analysis for GOOG.
#
# Processing ticker: MSFT
# Completed regression analysis for MSFT.
#
# Processing ticker: BRK-B
# BRK-B.csv does not exist in 'percent_changes'. Skipping.
#
# Processing ticker: AAPL
# Completed regression analysis for AAPL.
#
# Processing ticker: AMZN
# Completed regression analysis for AMZN.
#
# Processing ticker: JPM
# Completed regression analysis for JPM.
#
# Processing ticker: JNJ
# Completed regression analysis for JNJ.
#
# Processing ticker: NVDA
# Completed regression analysis for NVDA.
#
# Processing ticker: XOM
# Completed regression analysis for XOM.
#
# Processing ticker: V
# Completed regression analysis for V.
#
# Processing ticker: PG
# Completed regression analysis for PG.
#
# Processing ticker: META
# Completed regression analysis for META.
#
# Processing ticker: HD
# Completed regression analysis for HD.
#
# Processing ticker: SPY
# Completed regression analysis for SPY.
#
# Processing ticker: CVX
# Completed regression analysis for CVX.
#
# Processing ticker: MRK
# Completed regression analysis for MRK.
#
# Processing ticker: PEP
# Completed regression analysis for PEP.
#
# Processing ticker: ABBV
# Completed regression analysis for ABBV.
#
# Processing ticker: UNH
# Completed regression analysis for UNH.
#
# Processing ticker: COST
# Completed regression analysis for COST.
#
# Regression summary table saved to 'regression_results/regression_summary_table.csv'.
#
# Regression Summary Table:
#    Ticker Regression Type     Alpha   Beta_r1   Beta_r2   p_Alpha  p_Beta_r1  \
# 0    GOOG          Simple  0.096254  0.070728            0.103694   0.062758
# 1    GOOG        Multiple  0.107822  0.067451 -0.037142  0.149873   0.120937
# 2    MSFT          Simple -0.054497 -0.044565            0.663318   0.335145
# 3    MSFT        Multiple -0.065953 -0.058252 -0.068144  0.655849   0.383523
# 4    AAPL          Simple -0.024676 -0.266807            0.755375   0.064867
# 5    AAPL        Multiple  0.003026 -0.262059 -0.064304  0.977743   0.112464
# 6    AMZN          Simple  0.008242 -0.065695            0.942132   0.401756
# 7    AMZN        Multiple  0.007258 -0.171162 -0.223105  0.940884   0.147526
# 8     JPM          Simple  0.061324 -0.103068            0.093448   0.113556
# 9     JPM        Multiple  0.072846 -0.114959 -0.027741  0.180231   0.170450
# 10    JNJ          Simple -0.029046  0.103137            0.484814   0.236170
# 11    JNJ        Multiple -0.014812 -0.014122  0.101069  0.675735   0.887088
# 12   NVDA          Simple  0.225652 -0.006464            0.266381   0.853344
# 13   NVDA        Multiple -0.041408 -0.077076 -0.400943  0.886175   0.311331
# 14    XOM          Simple  0.093355 -0.326582            0.271897   0.060746
# 15    XOM        Multiple  0.107804 -0.304870  0.082074  0.276865   0.115573
# 16      V          Simple -0.005334  0.037187            0.890559   0.665686
# 17      V        Multiple -0.001892  0.044472  -0.01002  0.978394   0.768995
# 18     PG          Simple -0.000097 -0.087653            0.998512   0.131495
# 19     PG        Multiple  0.041949 -0.067554  0.085247  0.616202   0.309869
# 20   META          Simple  0.286543 -0.117702            0.055622   0.112015
# 21   META        Multiple  0.248126 -0.111487  0.060732  0.189835   0.190678
# 22     HD          Simple  0.074276 -0.254509            0.149874   0.068458
# 23     HD        Multiple  0.052245 -0.236403 -0.086631  0.290099   0.085323
# 24    SPY          Simple  0.048464 -0.036939            0.187146   0.392547
# 25    SPY        Multiple  0.048598 -0.040652  -0.02192  0.261440   0.580070
# 26    CVX          Simple  0.047968 -0.230109            0.772431   0.426150
# 27    CVX        Multiple -0.060188 -0.358162 -0.504542  0.782628   0.321621
# 28    MRK          Simple -0.010426 -0.132663            0.958594   0.602259
# 29    MRK        Multiple  0.064176 -0.183688  0.147803  0.839536   0.595557
# 30    PEP          Simple  0.010021 -0.168048            0.878505   0.146576
# 31    PEP        Multiple -0.016671 -0.129086 -0.072597  0.874568   0.437971
# 32   ABBV          Simple -0.097621  0.098368            0.489851   0.621246
# 33   ABBV        Multiple -0.104693  0.109305 -0.056618  0.526632   0.638902
# 34    UNH          Simple -0.051069  0.022867            0.459539   0.758010
# 35    UNH        Multiple -0.068649  0.011228  -0.08817  0.351108   0.878916
# 36   COST          Simple  0.153338  0.087006            0.313980   0.729788
# 37   COST        Multiple  0.309141  0.252851 -0.263831  0.211002   0.428689
#
#    p_Beta_r2  R-squared
# 0              0.620649
# 1   0.654596   0.649291
# 2              0.230526
# 3   0.716353   0.269370
# 4              0.614869
# 5   0.659161   0.643164
# 6              0.180022
# 7   0.204834   0.561235
# 8              0.504863
# 9    0.70524   0.531893
# 10             0.326510
# 11  0.184774   0.660008
# 12             0.009621
# 13  0.293737   0.355798
# 14             0.626275
# 15  0.538112   0.677853
# 16             0.051421
# 17  0.948183   0.052993
# 18             0.472189
# 19  0.497058   0.559405
# 20             0.507826
# 21  0.682286   0.539139
# 22             0.605276
# 23  0.258025   0.760247
# 24             0.186457
# 25  0.943648   0.188052
# 26             0.163744
# 27  0.435962   0.340501
# 28             0.101009
# 29  0.712337   0.175401
# 30             0.446969
# 31   0.72086   0.473992
# 32             0.066689
# 33  0.741149   0.105813
# 34             0.026492
# 35  0.339441   0.318357
# 36             0.033181
# 37  0.360426   0.302712
